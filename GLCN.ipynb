# %% [markdown]
# <a href="https://colab.research.google.com/github/broshanfekr/GLCN/blob/main/GLCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !wget -O data.zip https://www.dropbox.com/s/6aes8l4anfj07h3/data.zip?dl=0
# !unzip data.zip

# %%
import numpy as np
import scipy.sparse as sp
import sys
import scipy.io as sio
import tensorflow as tf
import time
import os

# %% [markdown]
# **مقدار دهی برخی از پارامترهای مربوط به آموزش مدل**

# %%
class Flags:
  def __init__(self):
    self.dataset = 'cora'
    self.model = 'sglcn'
    self.lr1 = 0.005
    self.lr2 = 0.005
    self.epochs = 10000
    self.hidden_gcn = 30
    self.hidden_gl = 70
    self.dropout = 0.6
    self.weight_decay = 1e-4
    self.early_stopping = 100
    self.losslr1 = 0.01
    self.losslr2 = 0.0001
    self.seed = 123

FLAGS = Flags()

# %% [markdown]
# **آماده سازی دیتاست جهت آموزش مدل**

# %%
def sample_mask(idx, l):
    """Create mask."""
    mask = np.zeros(l)
    mask[idx] = 1
    return np.array(mask, dtype=np.bool)


def load_data(dataset_str, path="data/"):
    path = path + dataset_str + "/"
    if dataset_str == "cora":
        features = sio.loadmat(path + "feature")
        features = features['matrix']
        adj = sio.loadmat(path + "adj")
        adj = adj['matrix']
        labels = sio.loadmat(path + "label")
        labels = labels['matrix']
        idx_train = range(140)
        idx_val = range(200, 500)
        idx_test = range(500, 1500)
    elif dataset_str == "citeseer":
        features = sio.loadmat(path + "feature")
        features = features['matrix']
        adj = sio.loadmat(path + "adj")
        adj = adj['matrix']
        labels = sio.loadmat(path + "label")
        labels = labels['matrix']
        idx_test = sio.loadmat(path + "test.mat")
        idx_test = idx_test['array'].flatten()
        idx_train = range(120)
        idx_val = range(120, 620)
    else:
        features = sio.loadmat(path + "feature")
        features = features['matrix']
        adj = sio.loadmat(path + "adj")
        adj = adj['matrix']
        labels = sio.loadmat(path + "label")
        labels = labels['matrix']
        idx_test = sio.loadmat(path + "test.mat")
        idx_test = idx_test['matrix']
        idx_train = range(60)
        idx_val = range(200, 500)

    adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
    train_mask = sample_mask(idx_train, labels.shape[0])
    val_mask = sample_mask(idx_val, labels.shape[0])
    test_mask = sample_mask(idx_test, labels.shape[0])

    y_train = np.zeros(labels.shape)
    y_val = np.zeros(labels.shape)
    y_test = np.zeros(labels.shape)
    y_train[train_mask, :] = labels[train_mask, :]
    y_val[val_mask, :] = labels[val_mask, :]
    y_test[test_mask, :] = labels[test_mask, :]

    return adj, features, y_train, y_val, y_test, train_mask, val_mask, test_mask

# %% [markdown]
# **پیش پردازش ویژگی ها و همچنین پیش پردازش و نرمال سازی ماتریس مجاورت**

# %%
def sparse_to_tuple(sparse_mx):
    """Convert sparse matrix to tuple representation."""
    def to_tuple(mx):
        if not sp.isspmatrix_coo(mx):
            mx = mx.tocoo()
        coords = np.vstack((mx.row, mx.col)).transpose()
        values = mx.data
        shape = mx.shape
        return coords, values, shape

    if isinstance(sparse_mx, list):
        for i in range(len(sparse_mx)):
            sparse_mx[i] = to_tuple(sparse_mx[i])
    else:
        sparse_mx = to_tuple(sparse_mx)

    return sparse_mx


def preprocess_features(features):
    """Row-normalize feature matrix and convert to tuple representation"""
    rowsum = np.array(features.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    features = r_mat_inv.dot(features)
    return sparse_to_tuple(features)


def normalize_adj(adj):
    """Symmetrically normalize adjacency matrix."""
    adj = sp.coo_matrix(adj)
    rowsum = np.array(adj.sum(1))
    d_inv_sqrt = np.power(rowsum, -0.5).flatten()
    d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
    d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
    return adj.dot(d_mat_inv_sqrt).transpose().dot(d_mat_inv_sqrt).tocoo()


def preprocess_adj(adj):
    """Preprocessing of adjacency matrix for simple GCN model and conversion to tuple representation."""
    adj_normalized = normalize_adj(adj + sp.eye(adj.shape[0]))
    edge = np.array(np.nonzero(adj_normalized.todense()))
    return sparse_to_tuple(adj_normalized), edge

# %% [markdown]
# **مقداردهی اولیه به وزن های شبکه عصبی و همچنین ایجاد ساختمان داده مربوط به ورودی شبکه عصبی**

# %%
def glorot(shape, name=None):
    """Glorot & Bengio (AISTATS 2010) init."""
    init_range = np.sqrt(6.0/(shape[0]+shape[1]))
    initial = tf.random_uniform(shape, minval=-init_range, maxval=init_range, dtype=tf.float32)
    return tf.Variable(initial, name=name)
    

def construct_feed_dict(features, adj, labels, labels_mask, epoch, placeholders):
    """Construct feed dictionary."""
    feed_dict = dict()
    feed_dict.update({placeholders['labels']: labels})
    feed_dict.update({placeholders['labels_mask']: labels_mask})
    feed_dict.update({placeholders['features']: features})
    feed_dict.update({placeholders['adj']: adj})
    feed_dict.update({placeholders['step']: epoch})
    feed_dict.update({placeholders['num_nodes']: features[2][0]})
    feed_dict.update({placeholders['num_features_nonzero']: features[1].shape})
    return feed_dict

# %% [markdown]
# **محاسبه معیارهای ارزیابی**

# %%
def masked_softmax_cross_entropy(preds, labels, mask):
    """Softmax cross-entropy loss with masking."""
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=preds, labels=labels)
    mask = tf.cast(mask, dtype=tf.float32)
    mask /= tf.reduce_mean(mask)
    loss *= mask
    return tf.reduce_mean(loss)


def masked_accuracy(preds, labels, mask):
    """Accuracy with masking."""
    correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(labels, 1))
    accuracy_all = tf.cast(correct_prediction, tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    mask /= tf.reduce_mean(mask)
    accuracy_all *= mask
    return tf.reduce_mean(accuracy_all)

# %% [markdown]
# **تعریف لایه کانولوشن گرافی و همچنین لایه مربوط به یادگیری ساختار گراف**

# %%
# global unique layer ID dictionary for layer name assignment
_LAYER_UIDS = {}


def get_layer_uid(layer_name=''):
    """Helper function, assigns unique layer IDs."""
    if layer_name not in _LAYER_UIDS:
        _LAYER_UIDS[layer_name] = 1
        return 1
    else:
        _LAYER_UIDS[layer_name] += 1
        return _LAYER_UIDS[layer_name]


def sparse_dropout(x, keep_prob, noise_shape):
    """Dropout for sparse tensors."""
    random_tensor = keep_prob
    random_tensor += tf.random_uniform(noise_shape)
    dropout_mask = tf.cast(tf.floor(random_tensor), dtype=tf.bool)
    pre_out = tf.sparse_retain(x, dropout_mask)
    return pre_out * (1./keep_prob)


def dot(x, y, sparse=False):
    """Wrapper for tf.matmul (sparse vs dense)."""
    if sparse:
        res = tf.sparse_tensor_dense_matmul(x, y)
    else:
        res = tf.matmul(x, y)
    return res


class SparseGraphLearn(object):
    """Sparse Graph learning layer."""
    def __init__(self, input_dim, output_dim, edge, placeholders, dropout=0.,
                 sparse_inputs=False, act=tf.nn.relu, bias=False, **kwargs):
        allowed_kwargs = {'name', 'logging'}
        for kwarg in kwargs.keys():
            assert kwarg in allowed_kwargs, 'Invalid keyword argument: ' + kwarg
        name = kwargs.get('name')
        if not name:
            layer = self.__class__.__name__.lower()
            name = layer + '_' + str(get_layer_uid(layer))
        self.name = name
        self.vars = {}

        if dropout:
            self.dropout = placeholders['dropout']
        else:
            self.dropout = 0.

        self.act = act
        self.num_nodes = placeholders['num_nodes']
        self.sparse_inputs = sparse_inputs
        self.bias = bias
        self.edge = edge

        # helper variable for sparse dropout
        self.num_features_nonzero = placeholders['num_features_nonzero']

        with tf.variable_scope(self.name + '_vars'):
            self.vars['weights'] = glorot([input_dim, output_dim], name='weights')
            self.vars['a'] = glorot([output_dim, 1], name='a')
            if self.bias:
                self.vars['bias'] = zeros([output_dim], name='bias')

    def __call__(self, inputs):
        x = inputs
        # dropout
        if self.sparse_inputs:
            x = sparse_dropout(x, 1-self.dropout, self.num_features_nonzero)
        else:
            x = tf.nn.dropout(x, 1-self.dropout)

        # graph learning
        h = dot(x, self.vars['weights'], sparse=self.sparse_inputs)
        N = self.num_nodes
        edge_v = tf.abs(tf.gather(h,self.edge[0]) - tf.gather(h,self.edge[1]))
        edge_v = tf.squeeze(self.act(dot(edge_v, self.vars['a'])))
        sgraph = tf.SparseTensor(indices=tf.transpose(self.edge), values=edge_v, dense_shape=[N, N])
        sgraph = tf.sparse_softmax(sgraph)
        return h, sgraph


class GraphConvolution(object):
    """Graph convolution layer provided by Thomas N. Kipf, Max Welling, 
    [Semi-Supervised Classification with Graph Convolutional Networks]
    (http://arxiv.org/abs/1609.02907) (ICLR 2017)"""
    def __init__(self, input_dim, output_dim, placeholders, dropout=0.,
                 sparse_inputs=False, act=tf.nn.relu, bias=False, **kwargs):
        allowed_kwargs = {'name', 'logging'}
        for kwarg in kwargs.keys():
            assert kwarg in allowed_kwargs, 'Invalid keyword argument: ' + kwarg
        name = kwargs.get('name')
        if not name:
            layer = self.__class__.__name__.lower()
            name = layer + '_' + str(get_layer_uid(layer))
        self.name = name
        self.vars = {}
        logging = kwargs.get('logging', False)
        self.logging = logging
        if dropout:
            self.dropout = placeholders['dropout']
        else:
            self.dropout = 0.

        self.act = act
        self.sparse_inputs = sparse_inputs
        self.bias = bias

        # helper variable for sparse dropout
        self.num_features_nonzero = placeholders['num_features_nonzero']

        with tf.variable_scope(self.name + '_vars'):
            self.vars['weights'] = glorot([input_dim, output_dim], name='weights')
            if self.bias:
                self.vars['bias'] = zeros([output_dim], name='bias')

        if self.logging:
            self._log_vars()

    def _call(self, inputs, adj):
        x = inputs

        # dropout
        if self.sparse_inputs:
            x = sparse_dropout(x, 1-self.dropout, self.num_features_nonzero)
        else:
            x = tf.nn.dropout(x, 1-self.dropout)

        # convolve
        pre_sup = dot(x, self.vars['weights'], sparse=self.sparse_inputs)
        output = dot(adj, pre_sup, sparse=True)

        # bias
        if self.bias:
            output += self.vars['bias']

        return self.act(output)

    def __call__(self, inputs, adj):
        with tf.name_scope(self.name):
            if self.logging and not self.sparse_inputs:
                tf.summary.histogram(self.name + '/inputs', inputs)
            outputs = self._call(inputs, adj)
            if self.logging:
                tf.summary.histogram(self.name + '/outputs', outputs)
            return outputs

    def _log_vars(self):
        for var in self.vars:
            tf.summary.histogram(self.name + '/vars/' + var, self.vars[var])

# %% [markdown]
# **ساخت مدل نهایی**

# %%
class SGLCN(object):
    def __init__(self, placeholders, edge, input_dim, **kwargs):
        allowed_kwargs = {'name', 'logging'}
        for kwarg in kwargs.keys():
            assert kwarg in allowed_kwargs, 'Invalid keyword argument: ' + kwarg
        name = kwargs.get('name')
        if not name:
            name = self.__class__.__name__.lower()
        self.name = name

        logging = kwargs.get('logging', False)
        self.logging = logging
        self.loss1 = 0
        self.loss2 = 0

        self.inputs = placeholders['features']
        self.edge = edge
        self.input_dim = input_dim
        # self.input_dim = self.inputs.get_shape().as_list()[1]  # To be supported in future Tensorflow versions
        self.output_dim = placeholders['labels'].get_shape().as_list()[1]
        self.placeholders = placeholders

        learning_rate1 = tf.train.exponential_decay(learning_rate=FLAGS.lr1, global_step=placeholders['step'],
                                                    decay_steps=100, decay_rate=0.9, staircase=True)
        learning_rate2 = tf.train.exponential_decay(learning_rate=FLAGS.lr2, global_step=placeholders['step'],
                                                    decay_steps=100, decay_rate=0.9, staircase=True)
        self.optimizer1 = tf.train.AdamOptimizer(learning_rate=learning_rate1)
        self.optimizer2 = tf.train.AdamOptimizer(learning_rate=learning_rate2)

        self.layers0 = SparseGraphLearn(input_dim=self.input_dim,
                                        output_dim=FLAGS.hidden_gl,
                                        edge=self.edge,
                                        placeholders=self.placeholders,
                                        act=tf.nn.relu,
                                        dropout=True,
                                        sparse_inputs=True)

        self.layers1 = GraphConvolution(input_dim=self.input_dim,
                                        output_dim=FLAGS.hidden_gcn,
                                        placeholders=self.placeholders,
                                        act=tf.nn.relu,
                                        dropout=True,
                                        sparse_inputs=True,
                                        logging=self.logging)

        self.layers2 = GraphConvolution(input_dim=FLAGS.hidden_gcn,
                                        output_dim=self.output_dim,
                                        placeholders=self.placeholders,
                                        act=lambda x: x,
                                        dropout=True,
                                        logging=self.logging)
        self.build()
        self.pro = tf.nn.softmax(self.outputs)

    def _loss(self):
        # Weight decay loss
        for var in self.layers0.vars.values():
            self.loss1 += FLAGS.weight_decay * tf.nn.l2_loss(var)
        for var in self.layers1.vars.values():
            self.loss2 += FLAGS.weight_decay * tf.nn.l2_loss(var)

        # Graph Learning loss
        D = tf.matrix_diag(tf.ones(self.placeholders['num_nodes']))*-1
        D = tf.sparse_add(D, self.S)*-1
        D = tf.matmul(tf.transpose(self.x), D)
        self.loss1 += tf.trace(tf.matmul(D, self.x)) * FLAGS.losslr1
        self.loss1 -= tf.trace(tf.sparse_tensor_dense_matmul(tf.sparse_transpose(self.S), tf.sparse_tensor_to_dense(self.S))) * FLAGS.losslr2

        # Cross entropy error
        self.loss2 += masked_softmax_cross_entropy(self.outputs, self.placeholders['labels'],
                                                  self.placeholders['labels_mask'])
       
        self.loss = self.loss1 + self.loss2

    def _accuracy(self):
        self.accuracy = masked_accuracy(self.outputs, self.placeholders['labels'],
                                        self.placeholders['labels_mask'])

    def build(self):
        self.x, self.S = self.layers0(self.inputs)

        x1 = self.layers1(self.inputs, self.S)
        self.outputs = self.layers2(x1, self.S)

        # Store model variables for easy access
        self.vars1 = tf.trainable_variables()[0:2]
        self.vars2 = tf.trainable_variables()[2:]

        # Build metrics
        self._loss()
        self._accuracy()

        self.opt_op1 = self.optimizer1.minimize(self.loss1, var_list=self.vars1)
        self.opt_op2 = self.optimizer2.minimize(self.loss2, var_list=self.vars2)
        self.opt_op = tf.group(self.opt_op1, self.opt_op2)

    def predict(self):
        return tf.nn.softmax(self.outputs)

# %%
# Define model evaluation function
def evaluate(features, adj, labels, mask, epoch, placeholders,flag=0):
    t_test = time.time()
    feed_dict_val = construct_feed_dict(features, adj, labels, mask, epoch, placeholders)
    if flag == 0:
        outs_val = sess.run([model.loss, model.accuracy], feed_dict=feed_dict_val)
        return outs_val[0], outs_val[1], (time.time() - t_test)
    else:
        outs_val = sess.run(model.accuracy, feed_dict=feed_dict_val)
        return outs_val

np.random.seed(FLAGS.seed)
tf.set_random_seed(FLAGS.seed)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '2'
# Load data
adj, features, y_train, y_val, y_test, train_mask, val_mask, test_mask = load_data(FLAGS.dataset)

# Some preprocessing
features = preprocess_features(features)
adj, edge = preprocess_adj(adj)

# Define placeholders
placeholders = {
    'adj': tf.sparse_placeholder(tf.float32),
    'features': tf.sparse_placeholder(tf.float32, shape=tf.constant(features[2], dtype=tf.int64)),
    'labels': tf.placeholder(tf.float32, shape=(None, y_train.shape[1])),
    'labels_mask': tf.placeholder(tf.int32),
    'dropout': tf.placeholder_with_default(0., shape=()),
    'num_nodes': tf.placeholder(tf.int32),
    'step': tf.placeholder(tf.int32),
    'num_features_nonzero': tf.placeholder(tf.int32)  # helper variable for sparse dropout
}

# Create model
model = SGLCN(placeholders, edge, input_dim=features[2][1], logging=True)

# Initialize session
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
config = tf.ConfigProto()  
config.gpu_options.per_process_gpu_memory_fraction = 1
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
# sess = tf.Session()

# Init variables
sess.run(tf.global_variables_initializer())
test_acc_list = []
best_epoch = 0
best = 10000

# Train model
for epoch in range(FLAGS.epochs):

    t = time.time()
    # Construct feed dictionary
    feed_dict = construct_feed_dict(features, adj, y_train, train_mask, epoch, placeholders)
    feed_dict.update({placeholders['dropout']: FLAGS.dropout})
    # Training step
    outs = sess.run([model.opt_op, model.loss, model.accuracy], feed_dict=feed_dict)
    # Validation
    cost, acc, duration = evaluate(features, adj, y_val, val_mask, epoch, placeholders)
    test_acc = evaluate(features, adj, y_test, test_mask, epoch, placeholders, flag=1)
    test_acc_list.append(test_acc)


    # Print results
    print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(outs[1]),
          "train_acc=", "{:.5f}".format(outs[2]), "val_loss=", "{:.5f}".format(cost),
          "val_acc=", "{:.5f}".format(acc), "test_acc=", "{:.5f}".format(test_acc), "time=", "{:.5f}".format(time.time() - t))

    if cost < best:
        best_epoch = epoch
        best = cost
        patience = 0

    else:
        patience += 1

    if patience == FLAGS.early_stopping:
        # feed_dict_val = construct_feed_dict(features, adj, y_test, test_mask, epoch, placeholders)
        # Smap = sess.run(tf.sparse_tensor_to_dense(model.S), feed_dict=feed_dict_val)
        # sio.savemat("S.mat", {'adjfix': np.array(Smap)})
        break
 
print("Optimization Finished!")
print("----------------------------------------------")
print("The finall result:", test_acc_list[-101])
print("----------------------------------------------")
# Out:
# WARNING:tensorflow:From <ipython-input-9-0aa71d5f0941>:129: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-8-056bee6d3e3f>:3: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Epoch: 0001 train_loss= 2.19247 train_acc= 0.21429 val_loss= 1.96447 val_acc= 0.26000 test_acc= 0.30400 time= 1.17653
# Epoch: 0002 train_loss= 2.11923 train_acc= 0.40000 val_loss= 1.94037 val_acc= 0.46333 test_acc= 0.43100 time= 0.39101
# Epoch: 0003 train_loss= 2.06540 train_acc= 0.50714 val_loss= 1.91946 val_acc= 0.54333 test_acc= 0.47400 time= 0.38197
# Epoch: 0004 train_loss= 2.02314 train_acc= 0.55000 val_loss= 1.90130 val_acc= 0.58333 test_acc= 0.47800 time= 0.38100
# Epoch: 0005 train_loss= 1.98001 train_acc= 0.57143 val_loss= 1.88563 val_acc= 0.59000 test_acc= 0.48000 time= 0.38008
# Epoch: 0006 train_loss= 1.94517 train_acc= 0.60714 val_loss= 1.87210 val_acc= 0.58667 test_acc= 0.47500 time= 0.39157
# Epoch: 0007 train_loss= 1.91580 train_acc= 0.57857 val_loss= 1.86040 val_acc= 0.58333 test_acc= 0.47700 time= 0.38058
# Epoch: 0008 train_loss= 1.89027 train_acc= 0.60000 val_loss= 1.85021 val_acc= 0.58667 test_acc= 0.48000 time= 0.39152
# Epoch: 0009 train_loss= 1.86795 train_acc= 0.63571 val_loss= 1.84117 val_acc= 0.58667 test_acc= 0.47700 time= 0.37375
# Epoch: 0010 train_loss= 1.85384 train_acc= 0.63571 val_loss= 1.83296 val_acc= 0.59667 test_acc= 0.47500 time= 0.39055
# Epoch: 0011 train_loss= 1.83579 train_acc= 0.62143 val_loss= 1.82534 val_acc= 0.60000 test_acc= 0.47700 time= 0.38488
# Epoch: 0012 train_loss= 1.82680 train_acc= 0.62143 val_loss= 1.81803 val_acc= 0.60667 test_acc= 0.47700 time= 0.36747
# Epoch: 0013 train_loss= 1.81623 train_acc= 0.64286 val_loss= 1.81083 val_acc= 0.60667 test_acc= 0.47800 time= 0.37596
# Epoch: 0014 train_loss= 1.80470 train_acc= 0.61429 val_loss= 1.80364 val_acc= 0.60333 test_acc= 0.47800 time= 0.39308
# Epoch: 0015 train_loss= 1.78814 train_acc= 0.62857 val_loss= 1.79618 val_acc= 0.60000 test_acc= 0.47600 time= 0.37449
# Epoch: 0016 train_loss= 1.77915 train_acc= 0.65000 val_loss= 1.78840 val_acc= 0.60000 test_acc= 0.47000 time= 0.40759
# Epoch: 0017 train_loss= 1.77908 train_acc= 0.65714 val_loss= 1.78035 val_acc= 0.59667 test_acc= 0.46900 time= 0.41287
# Epoch: 0018 train_loss= 1.77425 train_acc= 0.61429 val_loss= 1.77194 val_acc= 0.59667 test_acc= 0.46900 time= 0.36571
# Epoch: 0019 train_loss= 1.74376 train_acc= 0.65000 val_loss= 1.76315 val_acc= 0.59333 test_acc= 0.46500 time= 0.39120
# Epoch: 0020 train_loss= 1.74524 train_acc= 0.62857 val_loss= 1.75408 val_acc= 0.59333 test_acc= 0.46400 time= 0.38808
# Epoch: 0021 train_loss= 1.73633 train_acc= 0.65000 val_loss= 1.74471 val_acc= 0.59333 test_acc= 0.46400 time= 0.39092
# Epoch: 0022 train_loss= 1.71656 train_acc= 0.62857 val_loss= 1.73505 val_acc= 0.59333 test_acc= 0.46300 time= 0.38403
# Epoch: 0023 train_loss= 1.70671 train_acc= 0.65714 val_loss= 1.72513 val_acc= 0.59333 test_acc= 0.46200 time= 0.38571
# Epoch: 0024 train_loss= 1.70125 train_acc= 0.57143 val_loss= 1.71502 val_acc= 0.59000 test_acc= 0.45900 time= 0.41581
# Epoch: 0025 train_loss= 1.67445 train_acc= 0.60714 val_loss= 1.70464 val_acc= 0.59000 test_acc= 0.45800 time= 0.39414
# Epoch: 0026 train_loss= 1.65230 train_acc= 0.62857 val_loss= 1.69408 val_acc= 0.58667 test_acc= 0.45700 time= 0.40862
# Epoch: 0027 train_loss= 1.66064 train_acc= 0.62143 val_loss= 1.68341 val_acc= 0.58667 test_acc= 0.45600 time= 0.37418
# Epoch: 0028 train_loss= 1.64154 train_acc= 0.62857 val_loss= 1.67259 val_acc= 0.58667 test_acc= 0.45600 time= 0.37089
# Epoch: 0029 train_loss= 1.62253 train_acc= 0.62857 val_loss= 1.66158 val_acc= 0.58667 test_acc= 0.45400 time= 0.37617
# Epoch: 0030 train_loss= 1.60219 train_acc= 0.60000 val_loss= 1.65040 val_acc= 0.58667 test_acc= 0.45300 time= 0.37900
# Epoch: 0031 train_loss= 1.59486 train_acc= 0.65714 val_loss= 1.63915 val_acc= 0.58333 test_acc= 0.45400 time= 0.37230
# Epoch: 0032 train_loss= 1.60481 train_acc= 0.62143 val_loss= 1.62785 val_acc= 0.58333 test_acc= 0.45200 time= 0.37536
# Epoch: 0033 train_loss= 1.55983 train_acc= 0.62857 val_loss= 1.61639 val_acc= 0.58333 test_acc= 0.45100 time= 0.38039
# Epoch: 0034 train_loss= 1.55866 train_acc= 0.62857 val_loss= 1.60483 val_acc= 0.58333 test_acc= 0.45100 time= 0.37581
# Epoch: 0035 train_loss= 1.54313 train_acc= 0.62857 val_loss= 1.59312 val_acc= 0.58333 test_acc= 0.45100 time= 0.37876
# Epoch: 0036 train_loss= 1.52845 train_acc= 0.67143 val_loss= 1.58129 val_acc= 0.58333 test_acc= 0.45300 time= 0.37289
# Epoch: 0037 train_loss= 1.49442 train_acc= 0.69286 val_loss= 1.56935 val_acc= 0.59000 test_acc= 0.45400 time= 0.38233
# Epoch: 0038 train_loss= 1.49322 train_acc= 0.66429 val_loss= 1.55734 val_acc= 0.59333 test_acc= 0.45200 time= 0.36128
# Epoch: 0039 train_loss= 1.47141 train_acc= 0.62857 val_loss= 1.54525 val_acc= 0.59333 test_acc= 0.45200 time= 0.39553
# Epoch: 0040 train_loss= 1.46853 train_acc= 0.62143 val_loss= 1.53308 val_acc= 0.59333 test_acc= 0.45200 time= 0.39102
# Epoch: 0041 train_loss= 1.43822 train_acc= 0.64286 val_loss= 1.52080 val_acc= 0.59333 test_acc= 0.45300 time= 0.37221
# Epoch: 0042 train_loss= 1.42365 train_acc= 0.65000 val_loss= 1.50847 val_acc= 0.59667 test_acc= 0.45400 time= 0.36866
# Epoch: 0043 train_loss= 1.41442 train_acc= 0.62143 val_loss= 1.49616 val_acc= 0.59667 test_acc= 0.45700 time= 0.37978
# Epoch: 0044 train_loss= 1.40979 train_acc= 0.61429 val_loss= 1.48385 val_acc= 0.59667 test_acc= 0.46100 time= 0.37894
# Epoch: 0045 train_loss= 1.40381 train_acc= 0.66429 val_loss= 1.47156 val_acc= 0.60333 test_acc= 0.46600 time= 0.39548
# Epoch: 0046 train_loss= 1.36971 train_acc= 0.65714 val_loss= 1.45923 val_acc= 0.60333 test_acc= 0.46900 time= 0.40514
# Epoch: 0047 train_loss= 1.34190 train_acc= 0.65714 val_loss= 1.44689 val_acc= 0.61333 test_acc= 0.47300 time= 0.38973
# Epoch: 0048 train_loss= 1.36010 train_acc= 0.65714 val_loss= 1.43458 val_acc= 0.62000 test_acc= 0.47700 time= 0.40450
# Epoch: 0049 train_loss= 1.34387 train_acc= 0.66429 val_loss= 1.42234 val_acc= 0.62000 test_acc= 0.48400 time= 0.36359
# Epoch: 0050 train_loss= 1.32391 train_acc= 0.67857 val_loss= 1.41011 val_acc= 0.62000 test_acc= 0.48800 time= 0.38439
# Epoch: 0051 train_loss= 1.28242 train_acc= 0.67857 val_loss= 1.39789 val_acc= 0.62000 test_acc= 0.49200 time= 0.37432
# Epoch: 0052 train_loss= 1.28243 train_acc= 0.66429 val_loss= 1.38573 val_acc= 0.62333 test_acc= 0.49800 time= 0.37306
# Epoch: 0053 train_loss= 1.25946 train_acc= 0.70714 val_loss= 1.37361 val_acc= 0.63333 test_acc= 0.50700 time= 0.40846
# Epoch: 0054 train_loss= 1.24055 train_acc= 0.72143 val_loss= 1.36152 val_acc= 0.63667 test_acc= 0.51600 time= 0.37113
# Epoch: 0055 train_loss= 1.23358 train_acc= 0.69286 val_loss= 1.34951 val_acc= 0.63667 test_acc= 0.52500 time= 0.36720
# Epoch: 0056 train_loss= 1.21211 train_acc= 0.72143 val_loss= 1.33757 val_acc= 0.63667 test_acc= 0.53300 time= 0.37782
# Epoch: 0057 train_loss= 1.23142 train_acc= 0.71429 val_loss= 1.32574 val_acc= 0.63667 test_acc= 0.54200 time= 0.37339
# Epoch: 0058 train_loss= 1.16655 train_acc= 0.71429 val_loss= 1.31399 val_acc= 0.64667 test_acc= 0.54600 time= 0.36225
# Epoch: 0059 train_loss= 1.19447 train_acc= 0.69286 val_loss= 1.30232 val_acc= 0.65333 test_acc= 0.55200 time= 0.38078
# Epoch: 0060 train_loss= 1.17275 train_acc= 0.72857 val_loss= 1.29071 val_acc= 0.66667 test_acc= 0.55600 time= 0.36638
# Epoch: 0061 train_loss= 1.13267 train_acc= 0.77143 val_loss= 1.27920 val_acc= 0.67333 test_acc= 0.56200 time= 0.37152
# Epoch: 0062 train_loss= 1.11574 train_acc= 0.75000 val_loss= 1.26777 val_acc= 0.68333 test_acc= 0.57500 time= 0.36027
# Epoch: 0063 train_loss= 1.08750 train_acc= 0.77143 val_loss= 1.25648 val_acc= 0.69000 test_acc= 0.58100 time= 0.37090
# Epoch: 0064 train_loss= 1.10985 train_acc= 0.75714 val_loss= 1.24535 val_acc= 0.69667 test_acc= 0.59100 time= 0.38125
# Epoch: 0065 train_loss= 1.11646 train_acc= 0.76429 val_loss= 1.23441 val_acc= 0.70333 test_acc= 0.60600 time= 0.37870
# Epoch: 0066 train_loss= 1.06905 train_acc= 0.77857 val_loss= 1.22358 val_acc= 0.71000 test_acc= 0.62000 time= 0.37259
# Epoch: 0067 train_loss= 1.09521 train_acc= 0.75000 val_loss= 1.21287 val_acc= 0.71333 test_acc= 0.63100 time= 0.37354
# Epoch: 0068 train_loss= 1.03989 train_acc= 0.80714 val_loss= 1.20222 val_acc= 0.72000 test_acc= 0.64100 time= 0.37356
# Epoch: 0069 train_loss= 1.03339 train_acc= 0.77857 val_loss= 1.19174 val_acc= 0.72667 test_acc= 0.65000 time= 0.36484
# Epoch: 0070 train_loss= 1.03008 train_acc= 0.83571 val_loss= 1.18137 val_acc= 0.73667 test_acc= 0.65400 time= 0.37433
# Epoch: 0071 train_loss= 1.03670 train_acc= 0.78571 val_loss= 1.17115 val_acc= 0.73667 test_acc= 0.66100 time= 0.36679
# Epoch: 0072 train_loss= 1.01012 train_acc= 0.81429 val_loss= 1.16111 val_acc= 0.75333 test_acc= 0.66500 time= 0.38270
# Epoch: 0073 train_loss= 1.01992 train_acc= 0.81429 val_loss= 1.15119 val_acc= 0.75667 test_acc= 0.67200 time= 0.38061
# Epoch: 0074 train_loss= 0.98377 train_acc= 0.82143 val_loss= 1.14138 val_acc= 0.75667 test_acc= 0.67900 time= 0.38091
# Epoch: 0075 train_loss= 0.96784 train_acc= 0.81429 val_loss= 1.13167 val_acc= 0.76667 test_acc= 0.68600 time= 0.37547
# Epoch: 0076 train_loss= 0.97901 train_acc= 0.80000 val_loss= 1.12206 val_acc= 0.76667 test_acc= 0.68700 time= 0.38112
# Epoch: 0077 train_loss= 0.92262 train_acc= 0.83571 val_loss= 1.11262 val_acc= 0.76667 test_acc= 0.69500 time= 0.37292
# Epoch: 0078 train_loss= 0.90439 train_acc= 0.86429 val_loss= 1.10331 val_acc= 0.77000 test_acc= 0.69800 time= 0.37307
# Epoch: 0079 train_loss= 0.93790 train_acc= 0.82857 val_loss= 1.09411 val_acc= 0.77333 test_acc= 0.69800 time= 0.38124
# Epoch: 0080 train_loss= 0.89999 train_acc= 0.81429 val_loss= 1.08495 val_acc= 0.77667 test_acc= 0.70300 time= 0.38346
# Epoch: 0081 train_loss= 0.87738 train_acc= 0.87143 val_loss= 1.07599 val_acc= 0.78000 test_acc= 0.70900 time= 0.38174
# Epoch: 0082 train_loss= 0.90557 train_acc= 0.82143 val_loss= 1.06712 val_acc= 0.78000 test_acc= 0.71600 time= 0.38357
# Epoch: 0083 train_loss= 0.89148 train_acc= 0.84286 val_loss= 1.05843 val_acc= 0.78000 test_acc= 0.72100 time= 0.38604
# Epoch: 0084 train_loss= 0.85854 train_acc= 0.84286 val_loss= 1.04980 val_acc= 0.78333 test_acc= 0.72400 time= 0.36713
# Epoch: 0085 train_loss= 0.80779 train_acc= 0.87857 val_loss= 1.04139 val_acc= 0.78333 test_acc= 0.73000 time= 0.37148
# Epoch: 0086 train_loss= 0.83865 train_acc= 0.85000 val_loss= 1.03313 val_acc= 0.78333 test_acc= 0.73600 time= 0.37206
# Epoch: 0087 train_loss= 0.81696 train_acc= 0.85714 val_loss= 1.02511 val_acc= 0.78667 test_acc= 0.74200 time= 0.37613
# Epoch: 0088 train_loss= 0.82396 train_acc= 0.87143 val_loss= 1.01724 val_acc= 0.78667 test_acc= 0.74200 time= 0.36521
# Epoch: 0089 train_loss= 0.81851 train_acc= 0.87857 val_loss= 1.00957 val_acc= 0.78667 test_acc= 0.74500 time= 0.37170
# Epoch: 0090 train_loss= 0.79866 train_acc= 0.85000 val_loss= 1.00198 val_acc= 0.79000 test_acc= 0.74700 time= 0.38109
# Epoch: 0091 train_loss= 0.82244 train_acc= 0.85714 val_loss= 0.99465 val_acc= 0.79000 test_acc= 0.75000 time= 0.38527
# Epoch: 0092 train_loss= 0.76753 train_acc= 0.88571 val_loss= 0.98739 val_acc= 0.79000 test_acc= 0.75100 time= 0.36263
# Epoch: 0093 train_loss= 0.75174 train_acc= 0.87857 val_loss= 0.98025 val_acc= 0.79000 test_acc= 0.75200 time= 0.39176
# Epoch: 0094 train_loss= 0.79573 train_acc= 0.85000 val_loss= 0.97320 val_acc= 0.79333 test_acc= 0.75200 time= 0.38871
# Epoch: 0095 train_loss= 0.73923 train_acc= 0.86429 val_loss= 0.96621 val_acc= 0.80000 test_acc= 0.75600 time= 0.37209
# Epoch: 0096 train_loss= 0.80485 train_acc= 0.90000 val_loss= 0.95942 val_acc= 0.80000 test_acc= 0.75900 time= 0.37264
# Epoch: 0097 train_loss= 0.75429 train_acc= 0.86429 val_loss= 0.95277 val_acc= 0.80000 test_acc= 0.76400 time= 0.37774
# Epoch: 0098 train_loss= 0.75610 train_acc= 0.86429 val_loss= 0.94623 val_acc= 0.80667 test_acc= 0.76800 time= 0.36873
# Epoch: 0099 train_loss= 0.74871 train_acc= 0.86429 val_loss= 0.93979 val_acc= 0.80667 test_acc= 0.77100 time= 0.37873
# Epoch: 0100 train_loss= 0.72431 train_acc= 0.89286 val_loss= 0.93340 val_acc= 0.80667 test_acc= 0.77200 time= 0.37236
# Epoch: 0101 train_loss= 0.71569 train_acc= 0.85714 val_loss= 0.92777 val_acc= 0.80667 test_acc= 0.77400 time= 0.37922
# Epoch: 0102 train_loss= 0.69974 train_acc= 0.92857 val_loss= 0.92221 val_acc= 0.80667 test_acc= 0.77700 time= 0.38113
# Epoch: 0103 train_loss= 0.66675 train_acc= 0.90000 val_loss= 0.91687 val_acc= 0.81000 test_acc= 0.77900 time= 0.39051
# Epoch: 0104 train_loss= 0.74326 train_acc= 0.88571 val_loss= 0.91158 val_acc= 0.81000 test_acc= 0.77900 time= 0.37320
# Epoch: 0105 train_loss= 0.68677 train_acc= 0.88571 val_loss= 0.90637 val_acc= 0.81000 test_acc= 0.77900 time= 0.37595
# Epoch: 0106 train_loss= 0.66816 train_acc= 0.88571 val_loss= 0.90129 val_acc= 0.81000 test_acc= 0.78300 time= 0.37376
# Epoch: 0107 train_loss= 0.69748 train_acc= 0.86429 val_loss= 0.89624 val_acc= 0.81000 test_acc= 0.78500 time= 0.37559
# Epoch: 0108 train_loss= 0.71382 train_acc= 0.86429 val_loss= 0.89129 val_acc= 0.81000 test_acc= 0.78600 time= 0.37893
# Epoch: 0109 train_loss= 0.67077 train_acc= 0.87857 val_loss= 0.88629 val_acc= 0.81000 test_acc= 0.78600 time= 0.39115
# Epoch: 0110 train_loss= 0.61024 train_acc= 0.90714 val_loss= 0.88135 val_acc= 0.81000 test_acc= 0.78500 time= 0.37592
# Epoch: 0111 train_loss= 0.64969 train_acc= 0.86429 val_loss= 0.87645 val_acc= 0.81333 test_acc= 0.78900 time= 0.37916
# Epoch: 0112 train_loss= 0.65081 train_acc= 0.88571 val_loss= 0.87170 val_acc= 0.81333 test_acc= 0.79000 time= 0.39096
# Epoch: 0113 train_loss= 0.65864 train_acc= 0.90714 val_loss= 0.86702 val_acc= 0.81333 test_acc= 0.79100 time= 0.39812
# Epoch: 0114 train_loss= 0.63147 train_acc= 0.87143 val_loss= 0.86256 val_acc= 0.81333 test_acc= 0.79700 time= 0.37706
# Epoch: 0115 train_loss= 0.64788 train_acc= 0.89286 val_loss= 0.85825 val_acc= 0.81667 test_acc= 0.79700 time= 0.39884
# Epoch: 0116 train_loss= 0.60169 train_acc= 0.90714 val_loss= 0.85401 val_acc= 0.81667 test_acc= 0.79900 time= 0.38759
# Epoch: 0117 train_loss= 0.65948 train_acc= 0.88571 val_loss= 0.84985 val_acc= 0.81667 test_acc= 0.79900 time= 0.37345
# Epoch: 0118 train_loss= 0.58422 train_acc= 0.91429 val_loss= 0.84574 val_acc= 0.81333 test_acc= 0.80300 time= 0.38703
# Epoch: 0119 train_loss= 0.64066 train_acc= 0.87857 val_loss= 0.84167 val_acc= 0.81333 test_acc= 0.80400 time= 0.39136
# Epoch: 0120 train_loss= 0.62339 train_acc= 0.92857 val_loss= 0.83770 val_acc= 0.81000 test_acc= 0.80500 time= 0.39722
# Epoch: 0121 train_loss= 0.59244 train_acc= 0.91429 val_loss= 0.83379 val_acc= 0.81333 test_acc= 0.80500 time= 0.41759
# Epoch: 0122 train_loss= 0.57632 train_acc= 0.91429 val_loss= 0.83005 val_acc= 0.81333 test_acc= 0.80600 time= 0.40361
# Epoch: 0123 train_loss= 0.56674 train_acc= 0.90000 val_loss= 0.82647 val_acc= 0.81333 test_acc= 0.80800 time= 0.39151
# Epoch: 0124 train_loss= 0.63515 train_acc= 0.87143 val_loss= 0.82299 val_acc= 0.81667 test_acc= 0.80900 time= 0.39006
# Epoch: 0125 train_loss= 0.57944 train_acc= 0.90714 val_loss= 0.81954 val_acc= 0.81333 test_acc= 0.81000 time= 0.38570
# Epoch: 0126 train_loss= 0.59491 train_acc= 0.92143 val_loss= 0.81633 val_acc= 0.81667 test_acc= 0.81000 time= 0.38865
# Epoch: 0127 train_loss= 0.57679 train_acc= 0.91429 val_loss= 0.81328 val_acc= 0.82000 test_acc= 0.80900 time= 0.38430
# Epoch: 0128 train_loss= 0.59407 train_acc= 0.90000 val_loss= 0.81037 val_acc= 0.82333 test_acc= 0.81300 time= 0.39691
# Epoch: 0129 train_loss= 0.56182 train_acc= 0.92143 val_loss= 0.80759 val_acc= 0.82333 test_acc= 0.81400 time= 0.40765
# Epoch: 0130 train_loss= 0.53993 train_acc= 0.92143 val_loss= 0.80488 val_acc= 0.82333 test_acc= 0.81600 time= 0.38512
# Epoch: 0131 train_loss= 0.56609 train_acc= 0.90000 val_loss= 0.80227 val_acc= 0.82667 test_acc= 0.81700 time= 0.39184
# Epoch: 0132 train_loss= 0.50843 train_acc= 0.95714 val_loss= 0.79970 val_acc= 0.83000 test_acc= 0.81800 time= 0.39275
# Epoch: 0133 train_loss= 0.57910 train_acc= 0.90714 val_loss= 0.79721 val_acc= 0.83333 test_acc= 0.81800 time= 0.38658
# Epoch: 0134 train_loss= 0.58550 train_acc= 0.92857 val_loss= 0.79459 val_acc= 0.83333 test_acc= 0.81700 time= 0.39542
# Epoch: 0135 train_loss= 0.54425 train_acc= 0.95000 val_loss= 0.79205 val_acc= 0.83333 test_acc= 0.81800 time= 0.39031
# Epoch: 0136 train_loss= 0.53797 train_acc= 0.94286 val_loss= 0.78951 val_acc= 0.83333 test_acc= 0.81900 time= 0.39496
# Epoch: 0137 train_loss= 0.53461 train_acc= 0.94286 val_loss= 0.78696 val_acc= 0.83333 test_acc= 0.82000 time= 0.38393
# Epoch: 0138 train_loss= 0.56587 train_acc= 0.94286 val_loss= 0.78449 val_acc= 0.83667 test_acc= 0.82100 time= 0.38660
# Epoch: 0139 train_loss= 0.53770 train_acc= 0.90714 val_loss= 0.78210 val_acc= 0.83667 test_acc= 0.82200 time= 0.39530
# Epoch: 0140 train_loss= 0.50091 train_acc= 0.92143 val_loss= 0.77975 val_acc= 0.83667 test_acc= 0.82100 time= 0.37865
# Epoch: 0141 train_loss= 0.51784 train_acc= 0.92857 val_loss= 0.77752 val_acc= 0.83667 test_acc= 0.82200 time= 0.38362
# Epoch: 0142 train_loss= 0.52825 train_acc= 0.90714 val_loss= 0.77530 val_acc= 0.83667 test_acc= 0.82200 time= 0.38347
# Epoch: 0143 train_loss= 0.53030 train_acc= 0.92857 val_loss= 0.77320 val_acc= 0.84000 test_acc= 0.82200 time= 0.38371
# Epoch: 0144 train_loss= 0.55617 train_acc= 0.90714 val_loss= 0.77107 val_acc= 0.84000 test_acc= 0.82100 time= 0.39286
# Epoch: 0145 train_loss= 0.54396 train_acc= 0.91429 val_loss= 0.76899 val_acc= 0.84000 test_acc= 0.82000 time= 0.38970
# Epoch: 0146 train_loss= 0.50359 train_acc= 0.92143 val_loss= 0.76690 val_acc= 0.84000 test_acc= 0.82100 time= 0.37574
# Epoch: 0147 train_loss= 0.48716 train_acc= 0.94286 val_loss= 0.76484 val_acc= 0.84000 test_acc= 0.82300 time= 0.39490
# Epoch: 0148 train_loss= 0.47374 train_acc= 0.95000 val_loss= 0.76274 val_acc= 0.84000 test_acc= 0.82400 time= 0.38376
# Epoch: 0149 train_loss= 0.48519 train_acc= 0.93571 val_loss= 0.76062 val_acc= 0.84000 test_acc= 0.82600 time= 0.39902
# Epoch: 0150 train_loss= 0.45775 train_acc= 0.95000 val_loss= 0.75858 val_acc= 0.84000 test_acc= 0.82700 time= 0.38423
# Epoch: 0151 train_loss= 0.49173 train_acc= 0.94286 val_loss= 0.75655 val_acc= 0.84000 test_acc= 0.82800 time= 0.40832
# Epoch: 0152 train_loss= 0.50772 train_acc= 0.94286 val_loss= 0.75453 val_acc= 0.84000 test_acc= 0.82900 time= 0.39119
# Epoch: 0153 train_loss= 0.45692 train_acc= 0.94286 val_loss= 0.75259 val_acc= 0.84000 test_acc= 0.82900 time= 0.39067
# Epoch: 0154 train_loss= 0.48992 train_acc= 0.95000 val_loss= 0.75055 val_acc= 0.84000 test_acc= 0.82800 time= 0.41275
# Epoch: 0155 train_loss= 0.43768 train_acc= 0.96429 val_loss= 0.74860 val_acc= 0.84333 test_acc= 0.82900 time= 0.37878
# Epoch: 0156 train_loss= 0.46538 train_acc= 0.96429 val_loss= 0.74673 val_acc= 0.84333 test_acc= 0.82800 time= 0.37420
# Epoch: 0157 train_loss= 0.48624 train_acc= 0.96429 val_loss= 0.74491 val_acc= 0.84333 test_acc= 0.82800 time= 0.38937
# Epoch: 0158 train_loss= 0.45762 train_acc= 0.92143 val_loss= 0.74314 val_acc= 0.84333 test_acc= 0.82800 time= 0.37255
# Epoch: 0159 train_loss= 0.48289 train_acc= 0.92143 val_loss= 0.74143 val_acc= 0.84333 test_acc= 0.82800 time= 0.38592
# Epoch: 0160 train_loss= 0.49071 train_acc= 0.92857 val_loss= 0.73975 val_acc= 0.84333 test_acc= 0.82900 time= 0.39344
# Epoch: 0161 train_loss= 0.49504 train_acc= 0.91429 val_loss= 0.73798 val_acc= 0.84333 test_acc= 0.82900 time= 0.37619
# Epoch: 0162 train_loss= 0.45787 train_acc= 0.94286 val_loss= 0.73625 val_acc= 0.84333 test_acc= 0.83000 time= 0.38621
# Epoch: 0163 train_loss= 0.47890 train_acc= 0.92143 val_loss= 0.73461 val_acc= 0.84000 test_acc= 0.83400 time= 0.39358
# Epoch: 0164 train_loss= 0.46694 train_acc= 0.93571 val_loss= 0.73309 val_acc= 0.84000 test_acc= 0.83500 time= 0.39541
# Epoch: 0165 train_loss= 0.46895 train_acc= 0.94286 val_loss= 0.73161 val_acc= 0.83667 test_acc= 0.83600 time= 0.40910
# Epoch: 0166 train_loss= 0.45965 train_acc= 0.93571 val_loss= 0.73005 val_acc= 0.84000 test_acc= 0.83700 time= 0.38535
# Epoch: 0167 train_loss= 0.44242 train_acc= 0.94286 val_loss= 0.72842 val_acc= 0.84000 test_acc= 0.83700 time= 0.37495
# Epoch: 0168 train_loss= 0.46170 train_acc= 0.94286 val_loss= 0.72675 val_acc= 0.84000 test_acc= 0.83700 time= 0.38208
# Epoch: 0169 train_loss= 0.45169 train_acc= 0.92857 val_loss= 0.72509 val_acc= 0.84000 test_acc= 0.83900 time= 0.37034
# Epoch: 0170 train_loss= 0.42482 train_acc= 0.97143 val_loss= 0.72349 val_acc= 0.84000 test_acc= 0.83800 time= 0.38974
# Epoch: 0171 train_loss= 0.44313 train_acc= 0.94286 val_loss= 0.72202 val_acc= 0.84000 test_acc= 0.83900 time= 0.39032
# Epoch: 0172 train_loss= 0.47208 train_acc= 0.95714 val_loss= 0.72060 val_acc= 0.84000 test_acc= 0.84200 time= 0.39542
# Epoch: 0173 train_loss= 0.40378 train_acc= 0.95000 val_loss= 0.71925 val_acc= 0.84000 test_acc= 0.84200 time= 0.40670
# Epoch: 0174 train_loss= 0.41603 train_acc= 0.95000 val_loss= 0.71798 val_acc= 0.83667 test_acc= 0.84200 time= 0.37822
# Epoch: 0175 train_loss= 0.41537 train_acc= 0.95000 val_loss= 0.71678 val_acc= 0.83333 test_acc= 0.84300 time= 0.39166
# Epoch: 0176 train_loss= 0.47136 train_acc= 0.92857 val_loss= 0.71578 val_acc= 0.83333 test_acc= 0.84300 time= 0.38450
# Epoch: 0177 train_loss= 0.44745 train_acc= 0.92857 val_loss= 0.71477 val_acc= 0.83000 test_acc= 0.84300 time= 0.38931
# Epoch: 0178 train_loss= 0.40311 train_acc= 0.95000 val_loss= 0.71394 val_acc= 0.83000 test_acc= 0.84300 time= 0.37527
# Epoch: 0179 train_loss= 0.39380 train_acc= 0.97857 val_loss= 0.71316 val_acc= 0.83000 test_acc= 0.84300 time= 0.37900
# Epoch: 0180 train_loss= 0.44075 train_acc= 0.95714 val_loss= 0.71241 val_acc= 0.83000 test_acc= 0.84200 time= 0.38126
# Epoch: 0181 train_loss= 0.44549 train_acc= 0.92143 val_loss= 0.71154 val_acc= 0.83000 test_acc= 0.84300 time= 0.37764
# Epoch: 0182 train_loss= 0.40185 train_acc= 0.95000 val_loss= 0.71078 val_acc= 0.83000 test_acc= 0.84300 time= 0.37266
# Epoch: 0183 train_loss= 0.38183 train_acc= 0.98571 val_loss= 0.71009 val_acc= 0.83000 test_acc= 0.84300 time= 0.38495
# Epoch: 0184 train_loss= 0.40487 train_acc= 0.94286 val_loss= 0.70947 val_acc= 0.83333 test_acc= 0.84200 time= 0.38281
# Epoch: 0185 train_loss= 0.41894 train_acc= 0.95714 val_loss= 0.70887 val_acc= 0.83333 test_acc= 0.84300 time= 0.38085
# Epoch: 0186 train_loss= 0.36641 train_acc= 0.95000 val_loss= 0.70826 val_acc= 0.83333 test_acc= 0.84200 time= 0.38610
# Epoch: 0187 train_loss= 0.41503 train_acc= 0.93571 val_loss= 0.70776 val_acc= 0.83333 test_acc= 0.84200 time= 0.37742
# Epoch: 0188 train_loss= 0.39241 train_acc= 0.95000 val_loss= 0.70724 val_acc= 0.83333 test_acc= 0.84200 time= 0.38479
# Epoch: 0189 train_loss= 0.38957 train_acc= 0.97143 val_loss= 0.70667 val_acc= 0.83333 test_acc= 0.84200 time= 0.39225
# Epoch: 0190 train_loss= 0.39860 train_acc= 0.96429 val_loss= 0.70612 val_acc= 0.83333 test_acc= 0.84200 time= 0.38036
# Epoch: 0191 train_loss= 0.45117 train_acc= 0.95000 val_loss= 0.70559 val_acc= 0.83333 test_acc= 0.84000 time= 0.39335
# Epoch: 0192 train_loss= 0.41658 train_acc= 0.93571 val_loss= 0.70507 val_acc= 0.83333 test_acc= 0.84100 time= 0.41256
# Epoch: 0193 train_loss= 0.40608 train_acc= 0.94286 val_loss= 0.70446 val_acc= 0.83333 test_acc= 0.84200 time= 0.39843
# Epoch: 0194 train_loss= 0.39073 train_acc= 0.95000 val_loss= 0.70395 val_acc= 0.83333 test_acc= 0.84100 time= 0.39005
# Epoch: 0195 train_loss= 0.40301 train_acc= 0.97143 val_loss= 0.70330 val_acc= 0.83333 test_acc= 0.84300 time= 0.41095
# Epoch: 0196 train_loss= 0.37984 train_acc= 0.96429 val_loss= 0.70263 val_acc= 0.83333 test_acc= 0.84300 time= 0.41776
# Epoch: 0197 train_loss= 0.34514 train_acc= 0.97857 val_loss= 0.70190 val_acc= 0.83333 test_acc= 0.84300 time= 0.39150
# Epoch: 0198 train_loss= 0.40902 train_acc= 0.95000 val_loss= 0.70129 val_acc= 0.83333 test_acc= 0.84500 time= 0.38980
# Epoch: 0199 train_loss= 0.37023 train_acc= 0.95000 val_loss= 0.70052 val_acc= 0.83333 test_acc= 0.84500 time= 0.43154
# Epoch: 0200 train_loss= 0.38301 train_acc= 0.91429 val_loss= 0.69973 val_acc= 0.83333 test_acc= 0.84600 time= 0.39863
# Epoch: 0201 train_loss= 0.40100 train_acc= 0.94286 val_loss= 0.69899 val_acc= 0.83000 test_acc= 0.84900 time= 0.39471
# Epoch: 0202 train_loss= 0.40985 train_acc= 0.92857 val_loss= 0.69829 val_acc= 0.83000 test_acc= 0.84700 time= 0.40775
# Epoch: 0203 train_loss= 0.37972 train_acc= 0.97143 val_loss= 0.69752 val_acc= 0.83000 test_acc= 0.84700 time= 0.39747
# Epoch: 0204 train_loss= 0.34574 train_acc= 0.96429 val_loss= 0.69669 val_acc= 0.83000 test_acc= 0.84700 time= 0.40495
# Epoch: 0205 train_loss= 0.38452 train_acc= 0.95000 val_loss= 0.69603 val_acc= 0.83000 test_acc= 0.84900 time= 0.38127
# Epoch: 0206 train_loss= 0.36352 train_acc= 0.97857 val_loss= 0.69546 val_acc= 0.83000 test_acc= 0.84900 time= 0.37632
# Epoch: 0207 train_loss= 0.35493 train_acc= 0.97143 val_loss= 0.69486 val_acc= 0.83000 test_acc= 0.85100 time= 0.37565
# Epoch: 0208 train_loss= 0.36300 train_acc= 0.95714 val_loss= 0.69425 val_acc= 0.83000 test_acc= 0.85100 time= 0.37158
# Epoch: 0209 train_loss= 0.33075 train_acc= 0.97857 val_loss= 0.69364 val_acc= 0.83000 test_acc= 0.85100 time= 0.37003
# Epoch: 0210 train_loss= 0.34245 train_acc= 0.97143 val_loss= 0.69310 val_acc= 0.82667 test_acc= 0.85100 time= 0.37508
# Epoch: 0211 train_loss= 0.35753 train_acc= 0.95000 val_loss= 0.69259 val_acc= 0.82667 test_acc= 0.85100 time= 0.36989
# Epoch: 0212 train_loss= 0.35646 train_acc= 0.95000 val_loss= 0.69207 val_acc= 0.82667 test_acc= 0.85100 time= 0.39246
# Epoch: 0213 train_loss= 0.34677 train_acc= 0.95000 val_loss= 0.69147 val_acc= 0.82667 test_acc= 0.85000 time= 0.37739
# Epoch: 0214 train_loss= 0.38801 train_acc= 0.95000 val_loss= 0.69089 val_acc= 0.82667 test_acc= 0.85000 time= 0.38053
# Epoch: 0215 train_loss= 0.33920 train_acc= 0.97857 val_loss= 0.69020 val_acc= 0.82667 test_acc= 0.85000 time= 0.38999
# Epoch: 0216 train_loss= 0.34809 train_acc= 0.96429 val_loss= 0.68950 val_acc= 0.82667 test_acc= 0.85000 time= 0.37455
# Epoch: 0217 train_loss= 0.34916 train_acc= 0.97143 val_loss= 0.68886 val_acc= 0.82667 test_acc= 0.85000 time= 0.38810
# Epoch: 0218 train_loss= 0.38200 train_acc= 0.92857 val_loss= 0.68823 val_acc= 0.82667 test_acc= 0.85100 time= 0.38457
# Epoch: 0219 train_loss= 0.38243 train_acc= 0.96429 val_loss= 0.68755 val_acc= 0.82667 test_acc= 0.84900 time= 0.38194
# Epoch: 0220 train_loss= 0.35474 train_acc= 0.96429 val_loss= 0.68681 val_acc= 0.82667 test_acc= 0.85000 time= 0.38625
# Epoch: 0221 train_loss= 0.36399 train_acc= 0.97857 val_loss= 0.68608 val_acc= 0.82667 test_acc= 0.85100 time= 0.37274
# Epoch: 0222 train_loss= 0.35842 train_acc= 0.95714 val_loss= 0.68540 val_acc= 0.82667 test_acc= 0.85100 time= 0.37055
# Epoch: 0223 train_loss= 0.37684 train_acc= 0.96429 val_loss= 0.68483 val_acc= 0.82667 test_acc= 0.85200 time= 0.39178
# Epoch: 0224 train_loss= 0.34858 train_acc= 0.94286 val_loss= 0.68423 val_acc= 0.82667 test_acc= 0.85100 time= 0.39212
# Epoch: 0225 train_loss= 0.32695 train_acc= 0.95714 val_loss= 0.68370 val_acc= 0.82667 test_acc= 0.85000 time= 0.38465
# Epoch: 0226 train_loss= 0.34191 train_acc= 0.95714 val_loss= 0.68326 val_acc= 0.82667 test_acc= 0.85000 time= 0.38258
# Epoch: 0227 train_loss= 0.34417 train_acc= 0.97143 val_loss= 0.68279 val_acc= 0.82667 test_acc= 0.84900 time= 0.37401
# Epoch: 0228 train_loss= 0.35106 train_acc= 0.95714 val_loss= 0.68237 val_acc= 0.82667 test_acc= 0.85000 time= 0.38656
# Epoch: 0229 train_loss= 0.35220 train_acc= 0.95714 val_loss= 0.68200 val_acc= 0.82667 test_acc= 0.85000 time= 0.36578
# Epoch: 0230 train_loss= 0.35981 train_acc= 0.95714 val_loss= 0.68167 val_acc= 0.82667 test_acc= 0.85100 time= 0.37511
# Epoch: 0231 train_loss= 0.33343 train_acc= 0.95714 val_loss= 0.68140 val_acc= 0.82667 test_acc= 0.85100 time= 0.42574
# Epoch: 0232 train_loss= 0.34475 train_acc= 0.95000 val_loss= 0.68115 val_acc= 0.82667 test_acc= 0.85200 time= 0.39178
# Epoch: 0233 train_loss= 0.36475 train_acc= 0.95714 val_loss= 0.68098 val_acc= 0.82667 test_acc= 0.85200 time= 0.38093
# Epoch: 0234 train_loss= 0.32022 train_acc= 0.96429 val_loss= 0.68075 val_acc= 0.82667 test_acc= 0.85300 time= 0.38116
# Epoch: 0235 train_loss= 0.32784 train_acc= 0.96429 val_loss= 0.68059 val_acc= 0.82667 test_acc= 0.85300 time= 0.37306
# Epoch: 0236 train_loss= 0.39926 train_acc= 0.93571 val_loss= 0.68039 val_acc= 0.82667 test_acc= 0.85300 time= 0.38550
# Epoch: 0237 train_loss= 0.36575 train_acc= 0.92857 val_loss= 0.68026 val_acc= 0.82667 test_acc= 0.85300 time= 0.36530
# Epoch: 0238 train_loss= 0.32948 train_acc= 0.95714 val_loss= 0.68018 val_acc= 0.82667 test_acc= 0.85300 time= 0.37650
# Epoch: 0239 train_loss= 0.34121 train_acc= 0.97143 val_loss= 0.68016 val_acc= 0.82667 test_acc= 0.85300 time= 0.38234
# Epoch: 0240 train_loss= 0.35278 train_acc= 0.96429 val_loss= 0.68000 val_acc= 0.82333 test_acc= 0.85200 time= 0.37468
# Epoch: 0241 train_loss= 0.34423 train_acc= 0.94286 val_loss= 0.67995 val_acc= 0.82333 test_acc= 0.85100 time= 0.39098
# Epoch: 0242 train_loss= 0.38120 train_acc= 0.95000 val_loss= 0.67996 val_acc= 0.82333 test_acc= 0.85000 time= 0.39838
# Epoch: 0243 train_loss= 0.33736 train_acc= 0.97143 val_loss= 0.67986 val_acc= 0.82333 test_acc= 0.85100 time= 0.37584
# Epoch: 0244 train_loss= 0.35385 train_acc= 0.95714 val_loss= 0.67978 val_acc= 0.82000 test_acc= 0.85100 time= 0.40251
# Epoch: 0245 train_loss= 0.38101 train_acc= 0.92857 val_loss= 0.67978 val_acc= 0.82000 test_acc= 0.84900 time= 0.37976
# Epoch: 0246 train_loss= 0.32544 train_acc= 0.97143 val_loss= 0.67978 val_acc= 0.81667 test_acc= 0.84900 time= 0.37663
# Epoch: 0247 train_loss= 0.38654 train_acc= 0.95714 val_loss= 0.67974 val_acc= 0.81667 test_acc= 0.84900 time= 0.38761
# Epoch: 0248 train_loss= 0.34129 train_acc= 0.95000 val_loss= 0.67964 val_acc= 0.81667 test_acc= 0.84900 time= 0.37732
# Epoch: 0249 train_loss= 0.34192 train_acc= 0.97143 val_loss= 0.67933 val_acc= 0.81667 test_acc= 0.84900 time= 0.40002
# Epoch: 0250 train_loss= 0.28744 train_acc= 0.95000 val_loss= 0.67897 val_acc= 0.81667 test_acc= 0.84900 time= 0.40534
# Epoch: 0251 train_loss= 0.34945 train_acc= 0.97143 val_loss= 0.67860 val_acc= 0.81667 test_acc= 0.84900 time= 0.38726
# Epoch: 0252 train_loss= 0.29632 train_acc= 0.97143 val_loss= 0.67819 val_acc= 0.82000 test_acc= 0.84900 time= 0.39847
# Epoch: 0253 train_loss= 0.33327 train_acc= 0.95714 val_loss= 0.67775 val_acc= 0.82000 test_acc= 0.84900 time= 0.37518
# Epoch: 0254 train_loss= 0.35036 train_acc= 0.94286 val_loss= 0.67728 val_acc= 0.82000 test_acc= 0.85000 time= 0.38799
# Epoch: 0255 train_loss= 0.34167 train_acc= 0.95000 val_loss= 0.67677 val_acc= 0.82000 test_acc= 0.84900 time= 0.37859
# Epoch: 0256 train_loss= 0.29302 train_acc= 0.96429 val_loss= 0.67632 val_acc= 0.82333 test_acc= 0.84900 time= 0.36973
# Epoch: 0257 train_loss= 0.33815 train_acc= 0.95000 val_loss= 0.67587 val_acc= 0.82333 test_acc= 0.84800 time= 0.39073
# Epoch: 0258 train_loss= 0.34124 train_acc= 0.96429 val_loss= 0.67535 val_acc= 0.82667 test_acc= 0.84900 time= 0.39182
# Epoch: 0259 train_loss= 0.32882 train_acc= 0.97857 val_loss= 0.67495 val_acc= 0.82667 test_acc= 0.84900 time= 0.37458
# Epoch: 0260 train_loss= 0.32077 train_acc= 0.97143 val_loss= 0.67454 val_acc= 0.82667 test_acc= 0.84800 time= 0.38165
# Epoch: 0261 train_loss= 0.30708 train_acc= 0.95000 val_loss= 0.67425 val_acc= 0.82667 test_acc= 0.84900 time= 0.37542
# Epoch: 0262 train_loss= 0.30411 train_acc= 0.95000 val_loss= 0.67392 val_acc= 0.83000 test_acc= 0.85000 time= 0.37537
# Epoch: 0263 train_loss= 0.35447 train_acc= 0.93571 val_loss= 0.67349 val_acc= 0.83333 test_acc= 0.85100 time= 0.36945
# Epoch: 0264 train_loss= 0.29707 train_acc= 0.94286 val_loss= 0.67306 val_acc= 0.83333 test_acc= 0.85100 time= 0.35816
# Epoch: 0265 train_loss= 0.34670 train_acc= 0.95000 val_loss= 0.67250 val_acc= 0.83333 test_acc= 0.85100 time= 0.38461
# Epoch: 0266 train_loss= 0.36147 train_acc= 0.96429 val_loss= 0.67189 val_acc= 0.83333 test_acc= 0.85200 time= 0.38016
# Epoch: 0267 train_loss= 0.29116 train_acc= 0.97857 val_loss= 0.67132 val_acc= 0.83333 test_acc= 0.85400 time= 0.37827
# Epoch: 0268 train_loss= 0.30006 train_acc= 0.95000 val_loss= 0.67083 val_acc= 0.83333 test_acc= 0.85400 time= 0.38871
# Epoch: 0269 train_loss= 0.29265 train_acc= 0.95000 val_loss= 0.67038 val_acc= 0.83333 test_acc= 0.85400 time= 0.37784
# Epoch: 0270 train_loss= 0.32948 train_acc= 0.95000 val_loss= 0.66996 val_acc= 0.83333 test_acc= 0.85400 time= 0.37168
# Epoch: 0271 train_loss= 0.29209 train_acc= 0.98571 val_loss= 0.66961 val_acc= 0.83000 test_acc= 0.85300 time= 0.40815
# Epoch: 0272 train_loss= 0.36109 train_acc= 0.94286 val_loss= 0.66940 val_acc= 0.83000 test_acc= 0.85300 time= 0.37841
# Epoch: 0273 train_loss= 0.30272 train_acc= 0.95000 val_loss= 0.66922 val_acc= 0.83000 test_acc= 0.85300 time= 0.40555
# Epoch: 0274 train_loss= 0.33919 train_acc= 0.96429 val_loss= 0.66907 val_acc= 0.83000 test_acc= 0.85200 time= 0.40784
# Epoch: 0275 train_loss= 0.27775 train_acc= 0.97857 val_loss= 0.66902 val_acc= 0.82333 test_acc= 0.85300 time= 0.39843
# Epoch: 0276 train_loss= 0.28498 train_acc= 0.96429 val_loss= 0.66889 val_acc= 0.82333 test_acc= 0.85400 time= 0.42723
# Epoch: 0277 train_loss= 0.33230 train_acc= 0.95714 val_loss= 0.66871 val_acc= 0.82333 test_acc= 0.85400 time= 0.38421
# Epoch: 0278 train_loss= 0.32982 train_acc= 0.96429 val_loss= 0.66857 val_acc= 0.82333 test_acc= 0.85200 time= 0.38582
# Epoch: 0279 train_loss= 0.31942 train_acc= 0.98571 val_loss= 0.66844 val_acc= 0.82333 test_acc= 0.85200 time= 0.38285
# Epoch: 0280 train_loss= 0.31878 train_acc= 0.96429 val_loss= 0.66827 val_acc= 0.82333 test_acc= 0.85200 time= 0.38224
# Epoch: 0281 train_loss= 0.34350 train_acc= 0.96429 val_loss= 0.66804 val_acc= 0.82333 test_acc= 0.85300 time= 0.40204
# Epoch: 0282 train_loss= 0.28848 train_acc= 0.97857 val_loss= 0.66783 val_acc= 0.82333 test_acc= 0.85400 time= 0.38719
# Epoch: 0283 train_loss= 0.27858 train_acc= 0.98571 val_loss= 0.66765 val_acc= 0.82333 test_acc= 0.85300 time= 0.43159
# Epoch: 0284 train_loss= 0.31145 train_acc= 0.97143 val_loss= 0.66749 val_acc= 0.82667 test_acc= 0.85100 time= 0.37896
# Epoch: 0285 train_loss= 0.29838 train_acc= 0.97143 val_loss= 0.66721 val_acc= 0.82667 test_acc= 0.85200 time= 0.37279
# Epoch: 0286 train_loss= 0.31687 train_acc= 0.95000 val_loss= 0.66714 val_acc= 0.83000 test_acc= 0.85200 time= 0.40550
# Epoch: 0287 train_loss= 0.31506 train_acc= 0.96429 val_loss= 0.66707 val_acc= 0.83000 test_acc= 0.85200 time= 0.37590
# Epoch: 0288 train_loss= 0.28992 train_acc= 0.97857 val_loss= 0.66698 val_acc= 0.83000 test_acc= 0.85200 time= 0.37832
# Epoch: 0289 train_loss= 0.29252 train_acc= 0.95000 val_loss= 0.66686 val_acc= 0.83000 test_acc= 0.85400 time= 0.41260
# Epoch: 0290 train_loss= 0.31477 train_acc= 0.95714 val_loss= 0.66688 val_acc= 0.83000 test_acc= 0.85500 time= 0.40013
# Epoch: 0291 train_loss= 0.26994 train_acc= 0.99286 val_loss= 0.66687 val_acc= 0.83000 test_acc= 0.85500 time= 0.38575
# Epoch: 0292 train_loss= 0.29102 train_acc= 0.95714 val_loss= 0.66679 val_acc= 0.83000 test_acc= 0.85400 time= 0.37216
# Epoch: 0293 train_loss= 0.30632 train_acc= 0.97143 val_loss= 0.66670 val_acc= 0.83000 test_acc= 0.85400 time= 0.37945
# Epoch: 0294 train_loss= 0.31087 train_acc= 0.97857 val_loss= 0.66664 val_acc= 0.83000 test_acc= 0.85400 time= 0.38878
# Epoch: 0295 train_loss= 0.25884 train_acc= 0.97143 val_loss= 0.66656 val_acc= 0.83000 test_acc= 0.85300 time= 0.37648
# Epoch: 0296 train_loss= 0.29650 train_acc= 0.97143 val_loss= 0.66640 val_acc= 0.83000 test_acc= 0.85400 time= 0.39447
# Epoch: 0297 train_loss= 0.31728 train_acc= 0.96429 val_loss= 0.66625 val_acc= 0.83000 test_acc= 0.85400 time= 0.38339
# Epoch: 0298 train_loss= 0.30243 train_acc= 0.95714 val_loss= 0.66614 val_acc= 0.83000 test_acc= 0.85500 time= 0.39252
# Epoch: 0299 train_loss= 0.31884 train_acc= 0.94286 val_loss= 0.66620 val_acc= 0.83000 test_acc= 0.85400 time= 0.38266
# Epoch: 0300 train_loss= 0.26930 train_acc= 0.97143 val_loss= 0.66636 val_acc= 0.83000 test_acc= 0.85500 time= 0.36822
# Epoch: 0301 train_loss= 0.28961 train_acc= 0.94286 val_loss= 0.66660 val_acc= 0.83000 test_acc= 0.85600 time= 0.37982
# Epoch: 0302 train_loss= 0.29080 train_acc= 0.95000 val_loss= 0.66676 val_acc= 0.83000 test_acc= 0.85600 time= 0.38692
# Epoch: 0303 train_loss= 0.31043 train_acc= 0.96429 val_loss= 0.66685 val_acc= 0.83333 test_acc= 0.85600 time= 0.39513
# Epoch: 0304 train_loss= 0.28818 train_acc= 0.95000 val_loss= 0.66689 val_acc= 0.83333 test_acc= 0.85400 time= 0.38414
# Epoch: 0305 train_loss= 0.31258 train_acc= 0.95714 val_loss= 0.66699 val_acc= 0.83000 test_acc= 0.85600 time= 0.37807
# Epoch: 0306 train_loss= 0.24302 train_acc= 0.98571 val_loss= 0.66699 val_acc= 0.83000 test_acc= 0.85600 time= 0.40012
# Epoch: 0307 train_loss= 0.28209 train_acc= 0.98571 val_loss= 0.66682 val_acc= 0.83000 test_acc= 0.85500 time= 0.38101
# Epoch: 0308 train_loss= 0.30074 train_acc= 0.96429 val_loss= 0.66665 val_acc= 0.83000 test_acc= 0.85400 time= 0.42060
# Epoch: 0309 train_loss= 0.25951 train_acc= 0.97143 val_loss= 0.66645 val_acc= 0.83000 test_acc= 0.85400 time= 0.39865
# Epoch: 0310 train_loss= 0.26658 train_acc= 0.97143 val_loss= 0.66618 val_acc= 0.83000 test_acc= 0.85500 time= 0.37503
# Epoch: 0311 train_loss= 0.26405 train_acc= 0.97857 val_loss= 0.66588 val_acc= 0.83000 test_acc= 0.85500 time= 0.37492
# Epoch: 0312 train_loss= 0.29800 train_acc= 0.97143 val_loss= 0.66558 val_acc= 0.83000 test_acc= 0.85500 time= 0.39206
# Epoch: 0313 train_loss= 0.27136 train_acc= 0.97143 val_loss= 0.66539 val_acc= 0.83000 test_acc= 0.85500 time= 0.37887
# Epoch: 0314 train_loss= 0.31651 train_acc= 0.93571 val_loss= 0.66516 val_acc= 0.83000 test_acc= 0.85500 time= 0.38218
# Epoch: 0315 train_loss= 0.27527 train_acc= 0.97143 val_loss= 0.66498 val_acc= 0.83000 test_acc= 0.85500 time= 0.38732
# Epoch: 0316 train_loss= 0.28527 train_acc= 0.97143 val_loss= 0.66485 val_acc= 0.83000 test_acc= 0.85500 time= 0.38601
# Epoch: 0317 train_loss= 0.27824 train_acc= 0.96429 val_loss= 0.66469 val_acc= 0.83333 test_acc= 0.85600 time= 0.37849
# Epoch: 0318 train_loss= 0.27784 train_acc= 0.97857 val_loss= 0.66440 val_acc= 0.83333 test_acc= 0.85500 time= 0.38079
# Epoch: 0319 train_loss= 0.26701 train_acc= 0.97143 val_loss= 0.66421 val_acc= 0.83667 test_acc= 0.85700 time= 0.37901
# Epoch: 0320 train_loss= 0.28966 train_acc= 0.97857 val_loss= 0.66393 val_acc= 0.83667 test_acc= 0.85700 time= 0.38881
# Epoch: 0321 train_loss= 0.29910 train_acc= 0.97143 val_loss= 0.66359 val_acc= 0.83667 test_acc= 0.85700 time= 0.37294
# Epoch: 0322 train_loss= 0.28940 train_acc= 0.97143 val_loss= 0.66336 val_acc= 0.83667 test_acc= 0.85900 time= 0.37201
# Epoch: 0323 train_loss= 0.29527 train_acc= 0.95000 val_loss= 0.66318 val_acc= 0.83667 test_acc= 0.85800 time= 0.37539
# Epoch: 0324 train_loss= 0.29399 train_acc= 0.96429 val_loss= 0.66304 val_acc= 0.83667 test_acc= 0.85900 time= 0.36257
# Epoch: 0325 train_loss= 0.27634 train_acc= 0.96429 val_loss= 0.66297 val_acc= 0.83667 test_acc= 0.85700 time= 0.40390
# Epoch: 0326 train_loss= 0.28660 train_acc= 0.97143 val_loss= 0.66288 val_acc= 0.83333 test_acc= 0.85800 time= 0.38251
# Epoch: 0327 train_loss= 0.29709 train_acc= 0.96429 val_loss= 0.66270 val_acc= 0.83333 test_acc= 0.85900 time= 0.37756
# Epoch: 0328 train_loss= 0.33412 train_acc= 0.95714 val_loss= 0.66256 val_acc= 0.83333 test_acc= 0.85800 time= 0.40496
# Epoch: 0329 train_loss= 0.30091 train_acc= 0.97143 val_loss= 0.66238 val_acc= 0.83333 test_acc= 0.85800 time= 0.41072
# Epoch: 0330 train_loss= 0.29709 train_acc= 0.95714 val_loss= 0.66219 val_acc= 0.83333 test_acc= 0.85700 time= 0.41548
# Epoch: 0331 train_loss= 0.29683 train_acc= 0.96429 val_loss= 0.66194 val_acc= 0.83333 test_acc= 0.85700 time= 0.39950
# Epoch: 0332 train_loss= 0.28431 train_acc= 0.95000 val_loss= 0.66181 val_acc= 0.83333 test_acc= 0.85500 time= 0.37676
# Epoch: 0333 train_loss= 0.30920 train_acc= 0.97143 val_loss= 0.66171 val_acc= 0.83333 test_acc= 0.85600 time= 0.37671
# Epoch: 0334 train_loss= 0.24749 train_acc= 0.98571 val_loss= 0.66165 val_acc= 0.83333 test_acc= 0.85600 time= 0.38719
# Epoch: 0335 train_loss= 0.25363 train_acc= 0.96429 val_loss= 0.66163 val_acc= 0.83333 test_acc= 0.85600 time= 0.40033
# Epoch: 0336 train_loss= 0.26672 train_acc= 0.97143 val_loss= 0.66179 val_acc= 0.83333 test_acc= 0.85600 time= 0.37882
# Epoch: 0337 train_loss= 0.29930 train_acc= 0.96429 val_loss= 0.66186 val_acc= 0.83333 test_acc= 0.85700 time= 0.37699
# Epoch: 0338 train_loss= 0.34925 train_acc= 0.95714 val_loss= 0.66197 val_acc= 0.83333 test_acc= 0.85500 time= 0.37548
# Epoch: 0339 train_loss= 0.29073 train_acc= 0.97143 val_loss= 0.66207 val_acc= 0.83333 test_acc= 0.85300 time= 0.37886
# Epoch: 0340 train_loss= 0.28595 train_acc= 0.96429 val_loss= 0.66209 val_acc= 0.83000 test_acc= 0.85300 time= 0.37633
# Epoch: 0341 train_loss= 0.31123 train_acc= 0.95714 val_loss= 0.66229 val_acc= 0.83000 test_acc= 0.85300 time= 0.36887
# Epoch: 0342 train_loss= 0.28376 train_acc= 0.97857 val_loss= 0.66243 val_acc= 0.83000 test_acc= 0.85300 time= 0.37632
# Epoch: 0343 train_loss= 0.28040 train_acc= 0.97857 val_loss= 0.66272 val_acc= 0.82667 test_acc= 0.85400 time= 0.37078
# Epoch: 0344 train_loss= 0.28301 train_acc= 0.97143 val_loss= 0.66295 val_acc= 0.82667 test_acc= 0.85400 time= 0.38189
# Epoch: 0345 train_loss= 0.29353 train_acc= 0.96429 val_loss= 0.66333 val_acc= 0.82667 test_acc= 0.85400 time= 0.37201
# Epoch: 0346 train_loss= 0.26886 train_acc= 0.97143 val_loss= 0.66366 val_acc= 0.82333 test_acc= 0.85200 time= 0.37756
# Epoch: 0347 train_loss= 0.28771 train_acc= 0.96429 val_loss= 0.66397 val_acc= 0.82333 test_acc= 0.85100 time= 0.38747
# Epoch: 0348 train_loss= 0.25604 train_acc= 0.97857 val_loss= 0.66425 val_acc= 0.82333 test_acc= 0.85000 time= 0.39185
# Epoch: 0349 train_loss= 0.28825 train_acc= 0.99286 val_loss= 0.66455 val_acc= 0.82333 test_acc= 0.85000 time= 0.36833
# Epoch: 0350 train_loss= 0.25487 train_acc= 0.97857 val_loss= 0.66485 val_acc= 0.82333 test_acc= 0.84900 time= 0.37937
# Epoch: 0351 train_loss= 0.26747 train_acc= 0.97143 val_loss= 0.66505 val_acc= 0.82333 test_acc= 0.84900 time= 0.38059
# Epoch: 0352 train_loss= 0.27420 train_acc= 0.98571 val_loss= 0.66516 val_acc= 0.82333 test_acc= 0.85100 time= 0.42610
# Epoch: 0353 train_loss= 0.27564 train_acc= 0.97143 val_loss= 0.66502 val_acc= 0.82333 test_acc= 0.85000 time= 0.40230
# Epoch: 0354 train_loss= 0.25073 train_acc= 0.96429 val_loss= 0.66477 val_acc= 0.82333 test_acc= 0.85000 time= 0.43331
# Epoch: 0355 train_loss= 0.24388 train_acc= 0.96429 val_loss= 0.66448 val_acc= 0.82333 test_acc= 0.85200 time= 0.40430
# Epoch: 0356 train_loss= 0.28428 train_acc= 0.97143 val_loss= 0.66398 val_acc= 0.82333 test_acc= 0.85200 time= 0.42664
# Epoch: 0357 train_loss= 0.27953 train_acc= 0.96429 val_loss= 0.66348 val_acc= 0.82333 test_acc= 0.85300 time= 0.42512
# Epoch: 0358 train_loss= 0.28647 train_acc= 0.96429 val_loss= 0.66306 val_acc= 0.82333 test_acc= 0.85300 time= 0.38865
# Epoch: 0359 train_loss= 0.28652 train_acc= 0.95714 val_loss= 0.66277 val_acc= 0.82333 test_acc= 0.85300 time= 0.39581
# Epoch: 0360 train_loss= 0.28049 train_acc= 0.96429 val_loss= 0.66259 val_acc= 0.82333 test_acc= 0.85300 time= 0.38886
# Epoch: 0361 train_loss= 0.28451 train_acc= 0.96429 val_loss= 0.66244 val_acc= 0.82333 test_acc= 0.85300 time= 0.38414
# Epoch: 0362 train_loss= 0.24421 train_acc= 0.97143 val_loss= 0.66211 val_acc= 0.82333 test_acc= 0.85300 time= 0.38630
# Epoch: 0363 train_loss= 0.27473 train_acc= 0.97857 val_loss= 0.66171 val_acc= 0.82333 test_acc= 0.85300 time= 0.39038
# Epoch: 0364 train_loss= 0.24109 train_acc= 0.98571 val_loss= 0.66123 val_acc= 0.82333 test_acc= 0.85400 time= 0.39616
# Epoch: 0365 train_loss= 0.24340 train_acc= 0.96429 val_loss= 0.66078 val_acc= 0.82333 test_acc= 0.85300 time= 0.41516
# Epoch: 0366 train_loss= 0.26490 train_acc= 0.96429 val_loss= 0.66038 val_acc= 0.82333 test_acc= 0.85400 time= 0.39849
# Epoch: 0367 train_loss= 0.23306 train_acc= 0.99286 val_loss= 0.65996 val_acc= 0.82333 test_acc= 0.85400 time= 0.40051
# Epoch: 0368 train_loss= 0.28317 train_acc= 0.97143 val_loss= 0.65957 val_acc= 0.82333 test_acc= 0.85400 time= 0.37908
# Epoch: 0369 train_loss= 0.28827 train_acc= 0.97857 val_loss= 0.65922 val_acc= 0.82333 test_acc= 0.85400 time= 0.37257
# Epoch: 0370 train_loss= 0.22599 train_acc= 0.98571 val_loss= 0.65873 val_acc= 0.82333 test_acc= 0.85400 time= 0.39659
# Epoch: 0371 train_loss= 0.27566 train_acc= 0.96429 val_loss= 0.65832 val_acc= 0.82667 test_acc= 0.85500 time= 0.38654
# Epoch: 0372 train_loss= 0.26859 train_acc= 0.94286 val_loss= 0.65801 val_acc= 0.82667 test_acc= 0.85500 time= 0.39913
# Epoch: 0373 train_loss= 0.26397 train_acc= 0.97857 val_loss= 0.65766 val_acc= 0.82667 test_acc= 0.85500 time= 0.38174
# Epoch: 0374 train_loss= 0.27559 train_acc= 0.97857 val_loss= 0.65724 val_acc= 0.82667 test_acc= 0.85500 time= 0.68381
# Epoch: 0375 train_loss= 0.30259 train_acc= 0.96429 val_loss= 0.65688 val_acc= 0.82667 test_acc= 0.85400 time= 0.39026
# Epoch: 0376 train_loss= 0.26078 train_acc= 0.98571 val_loss= 0.65666 val_acc= 0.82667 test_acc= 0.85400 time= 0.36696
# Epoch: 0377 train_loss= 0.25753 train_acc= 0.97857 val_loss= 0.65646 val_acc= 0.82667 test_acc= 0.85300 time= 0.38423
# Epoch: 0378 train_loss= 0.26097 train_acc= 0.97143 val_loss= 0.65619 val_acc= 0.82667 test_acc= 0.85200 time= 0.38620
# Epoch: 0379 train_loss= 0.27854 train_acc= 0.97143 val_loss= 0.65594 val_acc= 0.82667 test_acc= 0.85200 time= 0.37925
# Epoch: 0380 train_loss= 0.28236 train_acc= 0.96429 val_loss= 0.65578 val_acc= 0.82667 test_acc= 0.85200 time= 0.40039
# Epoch: 0381 train_loss= 0.27701 train_acc= 0.95714 val_loss= 0.65565 val_acc= 0.82333 test_acc= 0.85100 time= 0.36960
# Epoch: 0382 train_loss= 0.24732 train_acc= 0.97857 val_loss= 0.65546 val_acc= 0.82333 test_acc= 0.85100 time= 0.38583
# Epoch: 0383 train_loss= 0.27563 train_acc= 0.97857 val_loss= 0.65518 val_acc= 0.82333 test_acc= 0.85000 time= 0.39839
# Epoch: 0384 train_loss= 0.28139 train_acc= 0.96429 val_loss= 0.65482 val_acc= 0.82333 test_acc= 0.85100 time= 0.40915
# Epoch: 0385 train_loss= 0.25041 train_acc= 0.97857 val_loss= 0.65455 val_acc= 0.82667 test_acc= 0.85100 time= 0.40286
# Epoch: 0386 train_loss= 0.24113 train_acc= 0.98571 val_loss= 0.65417 val_acc= 0.82667 test_acc= 0.85100 time= 0.37547
# Epoch: 0387 train_loss= 0.28648 train_acc= 0.95714 val_loss= 0.65372 val_acc= 0.82667 test_acc= 0.85100 time= 0.38242
# Epoch: 0388 train_loss= 0.29537 train_acc= 0.97143 val_loss= 0.65331 val_acc= 0.82667 test_acc= 0.85200 time= 0.39921
# Epoch: 0389 train_loss= 0.25250 train_acc= 0.97857 val_loss= 0.65302 val_acc= 0.82667 test_acc= 0.85100 time= 0.38052
# Epoch: 0390 train_loss= 0.26394 train_acc= 0.97143 val_loss= 0.65287 val_acc= 0.82667 test_acc= 0.85000 time= 0.40172
# Epoch: 0391 train_loss= 0.22962 train_acc= 0.97857 val_loss= 0.65294 val_acc= 0.82667 test_acc= 0.85100 time= 0.37413
# Epoch: 0392 train_loss= 0.24736 train_acc= 0.96429 val_loss= 0.65296 val_acc= 0.82667 test_acc= 0.85100 time= 0.39595
# Epoch: 0393 train_loss= 0.22449 train_acc= 0.98571 val_loss= 0.65298 val_acc= 0.82667 test_acc= 0.85100 time= 0.38065
# Epoch: 0394 train_loss= 0.25745 train_acc= 0.95714 val_loss= 0.65304 val_acc= 0.82333 test_acc= 0.85100 time= 0.37530
# Epoch: 0395 train_loss= 0.23840 train_acc= 0.98571 val_loss= 0.65314 val_acc= 0.82333 test_acc= 0.85100 time= 0.39538
# Epoch: 0396 train_loss= 0.25382 train_acc= 0.97857 val_loss= 0.65320 val_acc= 0.82000 test_acc= 0.85200 time= 0.39857
# Epoch: 0397 train_loss= 0.25348 train_acc= 0.96429 val_loss= 0.65326 val_acc= 0.82000 test_acc= 0.85200 time= 0.38777
# Epoch: 0398 train_loss= 0.26033 train_acc= 0.97143 val_loss= 0.65341 val_acc= 0.82000 test_acc= 0.85200 time= 0.38818
# Epoch: 0399 train_loss= 0.29097 train_acc= 0.94286 val_loss= 0.65351 val_acc= 0.82000 test_acc= 0.85200 time= 0.36524
# Epoch: 0400 train_loss= 0.22461 train_acc= 0.98571 val_loss= 0.65362 val_acc= 0.82000 test_acc= 0.85100 time= 0.36402
# Epoch: 0401 train_loss= 0.26059 train_acc= 0.96429 val_loss= 0.65390 val_acc= 0.82000 test_acc= 0.85300 time= 0.38934
# ...
# Epoch: 0475 train_loss= 0.21334 train_acc= 0.98571 val_loss= 0.64947 val_acc= 0.82667 test_acc= 0.85400 time= 0.38748
# Epoch: 0476 train_loss= 0.22268 train_acc= 0.98571 val_loss= 0.64941 val_acc= 0.82667 test_acc= 0.85300 time= 0.38106
# Epoch: 0477 train_loss= 0.23327 train_acc= 0.97143 val_loss= 0.64943 val_acc= 0.82667 test_acc= 0.85400 time= 0.38059
# Epoch: 0478 train_loss= 0.20974 train_acc= 0.97857 val_loss= 0.64946 val_acc= 0.82667 test_acc= 0.85500 time= 0.36485
# Epoch: 0479 train_loss= 0.22398 train_acc= 0.98571 val_loss= 0.64944 val_acc= 0.82667 test_acc= 0.85400 time= 0.37841
# Epoch: 0480 train_loss= 0.24645 train_acc= 0.96429 val_loss= 0.64953 val_acc= 0.82667 test_acc= 0.85400 time= 0.37993
# Epoch: 0481 train_loss= 0.25233 train_acc= 0.95714 val_loss= 0.64949 val_acc= 0.82333 test_acc= 0.85300 time= 0.38892
# Epoch: 0482 train_loss= 0.21606 train_acc= 0.98571 val_loss= 0.64946 val_acc= 0.82333 test_acc= 0.85400 time= 0.38160
# Epoch: 0483 train_loss= 0.18532 train_acc= 0.98571 val_loss= 0.64939 val_acc= 0.82333 test_acc= 0.85500 time= 0.40279
# Epoch: 0484 train_loss= 0.23016 train_acc= 0.97857 val_loss= 0.64926 val_acc= 0.82333 test_acc= 0.85400 time= 0.39597
# Epoch: 0485 train_loss= 0.21734 train_acc= 0.98571 val_loss= 0.64908 val_acc= 0.82333 test_acc= 0.85400 time= 0.38872
# Epoch: 0486 train_loss= 0.23862 train_acc= 0.97857 val_loss= 0.64887 val_acc= 0.82333 test_acc= 0.85400 time= 0.39543
# Epoch: 0487 train_loss= 0.23306 train_acc= 0.96429 val_loss= 0.64874 val_acc= 0.82333 test_acc= 0.85500 time= 0.39245
# Epoch: 0488 train_loss= 0.22878 train_acc= 0.95714 val_loss= 0.64850 val_acc= 0.82333 test_acc= 0.85500 time= 0.38816
# Epoch: 0489 train_loss= 0.19468 train_acc= 0.97857 val_loss= 0.64822 val_acc= 0.82333 test_acc= 0.85400 time= 0.42745
# Epoch: 0490 train_loss= 0.23353 train_acc= 0.97143 val_loss= 0.64802 val_acc= 0.82333 test_acc= 0.85400 time= 0.40150
# Epoch: 0491 train_loss= 0.21074 train_acc= 0.99286 val_loss= 0.64785 val_acc= 0.82333 test_acc= 0.85300 time= 0.41824
# Epoch: 0492 train_loss= 0.21145 train_acc= 0.98571 val_loss= 0.64786 val_acc= 0.82333 test_acc= 0.85400 time= 0.37885
# Epoch: 0493 train_loss= 0.23717 train_acc= 0.96429 val_loss= 0.64778 val_acc= 0.82333 test_acc= 0.85400 time= 0.40654
# Epoch: 0494 train_loss= 0.23188 train_acc= 0.97857 val_loss= 0.64768 val_acc= 0.82333 test_acc= 0.85400 time= 0.38255
# Epoch: 0495 train_loss= 0.24960 train_acc= 0.97143 val_loss= 0.64756 val_acc= 0.82333 test_acc= 0.85400 time= 0.38012
# Epoch: 0496 train_loss= 0.21990 train_acc= 0.97143 val_loss= 0.64749 val_acc= 0.82333 test_acc= 0.85300 time= 0.38788
# Epoch: 0497 train_loss= 0.23002 train_acc= 0.97143 val_loss= 0.64753 val_acc= 0.82333 test_acc= 0.85400 time= 0.38202
# Epoch: 0498 train_loss= 0.24531 train_acc= 0.98571 val_loss= 0.64760 val_acc= 0.82333 test_acc= 0.85300 time= 0.39709
# Epoch: 0499 train_loss= 0.19625 train_acc= 0.98571 val_loss= 0.64767 val_acc= 0.82333 test_acc= 0.85200 time= 0.38125
# Epoch: 0500 train_loss= 0.18919 train_acc= 0.99286 val_loss= 0.64769 val_acc= 0.82333 test_acc= 0.85200 time= 0.39113
# Epoch: 0501 train_loss= 0.19305 train_acc= 0.98571 val_loss= 0.64775 val_acc= 0.82333 test_acc= 0.85200 time= 0.41971
# Epoch: 0502 train_loss= 0.23189 train_acc= 0.97143 val_loss= 0.64780 val_acc= 0.82333 test_acc= 0.85100 time= 0.38061
# Epoch: 0503 train_loss= 0.21061 train_acc= 0.98571 val_loss= 0.64774 val_acc= 0.82333 test_acc= 0.85100 time= 0.40354
# Epoch: 0504 train_loss= 0.24207 train_acc= 0.97143 val_loss= 0.64767 val_acc= 0.82333 test_acc= 0.85100 time= 0.39267
# Epoch: 0505 train_loss= 0.21229 train_acc= 0.98571 val_loss= 0.64756 val_acc= 0.82333 test_acc= 0.85200 time= 0.39036
# Epoch: 0506 train_loss= 0.21775 train_acc= 0.97857 val_loss= 0.64742 val_acc= 0.82333 test_acc= 0.85300 time= 0.38431
# Epoch: 0507 train_loss= 0.22550 train_acc= 0.96429 val_loss= 0.64737 val_acc= 0.82333 test_acc= 0.85200 time= 0.40329
# Epoch: 0508 train_loss= 0.22453 train_acc= 0.98571 val_loss= 0.64734 val_acc= 0.82333 test_acc= 0.85200 time= 0.41225
# Epoch: 0509 train_loss= 0.25690 train_acc= 0.96429 val_loss= 0.64742 val_acc= 0.82333 test_acc= 0.85300 time= 0.38586
# Epoch: 0510 train_loss= 0.21071 train_acc= 0.97143 val_loss= 0.64751 val_acc= 0.82333 test_acc= 0.85300 time= 0.42062
# Epoch: 0511 train_loss= 0.21435 train_acc= 0.97143 val_loss= 0.64762 val_acc= 0.82333 test_acc= 0.85200 time= 0.43345
# Epoch: 0512 train_loss= 0.24883 train_acc= 0.95714 val_loss= 0.64761 val_acc= 0.82333 test_acc= 0.85300 time= 0.42502
# Epoch: 0513 train_loss= 0.23284 train_acc= 0.95714 val_loss= 0.64766 val_acc= 0.82333 test_acc= 0.85400 time= 0.44760
# Epoch: 0514 train_loss= 0.24457 train_acc= 0.98571 val_loss= 0.64778 val_acc= 0.82333 test_acc= 0.85400 time= 0.40774
# Epoch: 0515 train_loss= 0.19358 train_acc= 0.97143 val_loss= 0.64787 val_acc= 0.82333 test_acc= 0.85400 time= 0.41342
# Epoch: 0516 train_loss= 0.23152 train_acc= 0.97143 val_loss= 0.64796 val_acc= 0.82333 test_acc= 0.85400 time= 0.43280
# Epoch: 0517 train_loss= 0.22519 train_acc= 0.97143 val_loss= 0.64803 val_acc= 0.82333 test_acc= 0.85400 time= 0.40782
# Epoch: 0518 train_loss= 0.25386 train_acc= 0.96429 val_loss= 0.64818 val_acc= 0.82333 test_acc= 0.85300 time= 0.40277
# Epoch: 0519 train_loss= 0.23414 train_acc= 0.97143 val_loss= 0.64839 val_acc= 0.82333 test_acc= 0.85300 time= 0.40925
# Epoch: 0520 train_loss= 0.23990 train_acc= 0.97857 val_loss= 0.64863 val_acc= 0.82000 test_acc= 0.85300 time= 0.42547
# Epoch: 0521 train_loss= 0.21609 train_acc= 0.98571 val_loss= 0.64889 val_acc= 0.82000 test_acc= 0.85300 time= 0.38814
# Epoch: 0522 train_loss= 0.22412 train_acc= 0.97857 val_loss= 0.64917 val_acc= 0.82000 test_acc= 0.85400 time= 0.38322
# Epoch: 0523 train_loss= 0.24218 train_acc= 0.99286 val_loss= 0.64944 val_acc= 0.82000 test_acc= 0.85400 time= 0.38276
# Epoch: 0524 train_loss= 0.21789 train_acc= 0.99286 val_loss= 0.64980 val_acc= 0.82000 test_acc= 0.85400 time= 0.37811
# Epoch: 0525 train_loss= 0.22797 train_acc= 0.96429 val_loss= 0.65020 val_acc= 0.82000 test_acc= 0.85300 time= 0.37402
# Epoch: 0526 train_loss= 0.22340 train_acc= 0.97857 val_loss= 0.65055 val_acc= 0.82000 test_acc= 0.85300 time= 0.40084
# Epoch: 0527 train_loss= 0.20458 train_acc= 0.97143 val_loss= 0.65094 val_acc= 0.82000 test_acc= 0.85300 time= 0.36086
# Epoch: 0528 train_loss= 0.19220 train_acc= 0.97857 val_loss= 0.65150 val_acc= 0.82000 test_acc= 0.85300 time= 0.37979
# Epoch: 0529 train_loss= 0.23041 train_acc= 0.95714 val_loss= 0.65192 val_acc= 0.82000 test_acc= 0.85400 time= 0.38619
# Epoch: 0530 train_loss= 0.21824 train_acc= 0.96429 val_loss= 0.65256 val_acc= 0.82000 test_acc= 0.85400 time= 0.39035
# Epoch: 0531 train_loss= 0.18857 train_acc= 0.98571 val_loss= 0.65311 val_acc= 0.82000 test_acc= 0.85300 time= 0.40324
# Epoch: 0532 train_loss= 0.21564 train_acc= 0.99286 val_loss= 0.65356 val_acc= 0.82000 test_acc= 0.85300 time= 0.38294
# Epoch: 0533 train_loss= 0.21867 train_acc= 0.97857 val_loss= 0.65377 val_acc= 0.82000 test_acc= 0.85200 time= 0.40077
# Epoch: 0534 train_loss= 0.19046 train_acc= 0.98571 val_loss= 0.65398 val_acc= 0.82000 test_acc= 0.85200 time= 0.40449
# Epoch: 0535 train_loss= 0.20516 train_acc= 0.99286 val_loss= 0.65416 val_acc= 0.82000 test_acc= 0.85100 time= 0.40970
# Epoch: 0536 train_loss= 0.24149 train_acc= 0.97143 val_loss= 0.65424 val_acc= 0.82000 test_acc= 0.85100 time= 0.39320
# Epoch: 0537 train_loss= 0.22714 train_acc= 0.95714 val_loss= 0.65426 val_acc= 0.82000 test_acc= 0.85100 time= 0.40313
# Epoch: 0538 train_loss= 0.22855 train_acc= 0.97143 val_loss= 0.65430 val_acc= 0.82000 test_acc= 0.85100 time= 0.43509
# Epoch: 0539 train_loss= 0.25923 train_acc= 0.95714 val_loss= 0.65425 val_acc= 0.82000 test_acc= 0.85100 time= 0.46833
# Epoch: 0540 train_loss= 0.18955 train_acc= 0.98571 val_loss= 0.65432 val_acc= 0.82000 test_acc= 0.85100 time= 0.40069
# Epoch: 0541 train_loss= 0.20994 train_acc= 0.97857 val_loss= 0.65414 val_acc= 0.82000 test_acc= 0.85100 time= 0.43771
# Epoch: 0542 train_loss= 0.21145 train_acc= 0.97857 val_loss= 0.65399 val_acc= 0.82000 test_acc= 0.85000 time= 0.40174
# Epoch: 0543 train_loss= 0.22153 train_acc= 0.96429 val_loss= 0.65400 val_acc= 0.82000 test_acc= 0.85000 time= 0.39647
# Epoch: 0544 train_loss= 0.21876 train_acc= 0.95714 val_loss= 0.65385 val_acc= 0.82000 test_acc= 0.85000 time= 0.41339
# Epoch: 0545 train_loss= 0.20413 train_acc= 0.98571 val_loss= 0.65383 val_acc= 0.82000 test_acc= 0.85000 time= 0.38260
# Epoch: 0546 train_loss= 0.25219 train_acc= 0.95000 val_loss= 0.65396 val_acc= 0.82000 test_acc= 0.85000 time= 0.37885
# Epoch: 0547 train_loss= 0.21675 train_acc= 0.96429 val_loss= 0.65409 val_acc= 0.82000 test_acc= 0.85000 time= 0.36343
# Epoch: 0548 train_loss= 0.20813 train_acc= 0.99286 val_loss= 0.65427 val_acc= 0.82000 test_acc= 0.84900 time= 0.40144
# Epoch: 0549 train_loss= 0.22176 train_acc= 0.97857 val_loss= 0.65456 val_acc= 0.82000 test_acc= 0.84800 time= 0.38409
# Epoch: 0550 train_loss= 0.21214 train_acc= 0.98571 val_loss= 0.65469 val_acc= 0.82000 test_acc= 0.84800 time= 0.38949
# Epoch: 0551 train_loss= 0.25893 train_acc= 0.97143 val_loss= 0.65464 val_acc= 0.82000 test_acc= 0.84800 time= 0.39460
# Epoch: 0552 train_loss= 0.25902 train_acc= 0.95714 val_loss= 0.65463 val_acc= 0.82000 test_acc= 0.84800 time= 0.36966
# Epoch: 0553 train_loss= 0.23582 train_acc= 0.97143 val_loss= 0.65472 val_acc= 0.82000 test_acc= 0.84800 time= 0.37623
# Epoch: 0554 train_loss= 0.21908 train_acc= 0.97857 val_loss= 0.65476 val_acc= 0.82000 test_acc= 0.84800 time= 0.39093
# Epoch: 0555 train_loss= 0.17567 train_acc= 0.99286 val_loss= 0.65476 val_acc= 0.82000 test_acc= 0.84800 time= 0.37460
# Epoch: 0556 train_loss= 0.22606 train_acc= 0.94286 val_loss= 0.65475 val_acc= 0.82000 test_acc= 0.84800 time= 0.40760
# Epoch: 0557 train_loss= 0.20930 train_acc= 0.98571 val_loss= 0.65469 val_acc= 0.82000 test_acc= 0.85000 time= 0.38840
# Epoch: 0558 train_loss= 0.23987 train_acc= 0.96429 val_loss= 0.65469 val_acc= 0.82000 test_acc= 0.85000 time= 0.37939
# Epoch: 0559 train_loss= 0.19333 train_acc= 0.98571 val_loss= 0.65473 val_acc= 0.82000 test_acc= 0.85000 time= 0.37979
# Epoch: 0560 train_loss= 0.20478 train_acc= 0.98571 val_loss= 0.65469 val_acc= 0.82000 test_acc= 0.85000 time= 0.39428
# Epoch: 0561 train_loss= 0.24740 train_acc= 0.95714 val_loss= 0.65467 val_acc= 0.82000 test_acc= 0.85100 time= 0.37623
# Epoch: 0562 train_loss= 0.21315 train_acc= 0.97143 val_loss= 0.65480 val_acc= 0.82000 test_acc= 0.85200 time= 0.37610
# Epoch: 0563 train_loss= 0.25686 train_acc= 0.96429 val_loss= 0.65478 val_acc= 0.82000 test_acc= 0.85300 time= 0.38981
# Epoch: 0564 train_loss= 0.20840 train_acc= 0.96429 val_loss= 0.65459 val_acc= 0.82000 test_acc= 0.85300 time= 0.39031
# Epoch: 0565 train_loss= 0.20258 train_acc= 0.99286 val_loss= 0.65445 val_acc= 0.82000 test_acc= 0.85300 time= 0.40556
# Epoch: 0566 train_loss= 0.20705 train_acc= 0.97857 val_loss= 0.65426 val_acc= 0.82000 test_acc= 0.85300 time= 0.40958
# Epoch: 0567 train_loss= 0.20000 train_acc= 0.98571 val_loss= 0.65398 val_acc= 0.82000 test_acc= 0.85300 time= 0.39945
# Epoch: 0568 train_loss= 0.20736 train_acc= 0.97857 val_loss= 0.65372 val_acc= 0.82000 test_acc= 0.85300 time= 0.39660
# Epoch: 0569 train_loss= 0.23111 train_acc= 0.97857 val_loss= 0.65357 val_acc= 0.82000 test_acc= 0.85300 time= 0.38001
# Epoch: 0570 train_loss= 0.19112 train_acc= 0.97857 val_loss= 0.65330 val_acc= 0.82000 test_acc= 0.85300 time= 0.38093
# Epoch: 0571 train_loss= 0.19363 train_acc= 0.98571 val_loss= 0.65309 val_acc= 0.82000 test_acc= 0.85300 time= 0.38538
# Epoch: 0572 train_loss= 0.22342 train_acc= 0.97857 val_loss= 0.65288 val_acc= 0.82000 test_acc= 0.85400 time= 0.39027
# Epoch: 0573 train_loss= 0.20794 train_acc= 0.99286 val_loss= 0.65254 val_acc= 0.82000 test_acc= 0.85500 time= 0.38847
# Epoch: 0574 train_loss= 0.19732 train_acc= 1.00000 val_loss= 0.65222 val_acc= 0.82000 test_acc= 0.85400 time= 0.38582
# Epoch: 0575 train_loss= 0.20348 train_acc= 0.97857 val_loss= 0.65203 val_acc= 0.82000 test_acc= 0.85300 time= 0.37570
# Epoch: 0576 train_loss= 0.21683 train_acc= 0.97857 val_loss= 0.65178 val_acc= 0.82000 test_acc= 0.85300 time= 0.37549
# Epoch: 0577 train_loss= 0.19358 train_acc= 1.00000 val_loss= 0.65163 val_acc= 0.82000 test_acc= 0.85300 time= 0.37679
# Epoch: 0578 train_loss= 0.18729 train_acc= 0.97143 val_loss= 0.65162 val_acc= 0.82000 test_acc= 0.85300 time= 0.37100
# Epoch: 0579 train_loss= 0.23416 train_acc= 0.97143 val_loss= 0.65167 val_acc= 0.82000 test_acc= 0.85300 time= 0.37586
# Epoch: 0580 train_loss= 0.17522 train_acc= 0.99286 val_loss= 0.65163 val_acc= 0.82000 test_acc= 0.85300 time= 0.37765
# Epoch: 0581 train_loss= 0.20819 train_acc= 0.97857 val_loss= 0.65142 val_acc= 0.82000 test_acc= 0.85300 time= 0.37667
# Epoch: 0582 train_loss= 0.24591 train_acc= 0.96429 val_loss= 0.65123 val_acc= 0.82000 test_acc= 0.85300 time= 0.37653
# Epoch: 0583 train_loss= 0.22069 train_acc= 0.97143 val_loss= 0.65105 val_acc= 0.82000 test_acc= 0.85300 time= 0.37212
# Epoch: 0584 train_loss= 0.21502 train_acc= 0.98571 val_loss= 0.65091 val_acc= 0.82000 test_acc= 0.85300 time= 0.36680
# Epoch: 0585 train_loss= 0.21072 train_acc= 0.98571 val_loss= 0.65103 val_acc= 0.82000 test_acc= 0.85300 time= 0.37836
# Epoch: 0586 train_loss= 0.23748 train_acc= 0.96429 val_loss= 0.65119 val_acc= 0.82000 test_acc= 0.85300 time= 0.37367
# Epoch: 0587 train_loss= 0.22418 train_acc= 0.96429 val_loss= 0.65130 val_acc= 0.82000 test_acc= 0.85300 time= 0.36736
# Epoch: 0588 train_loss= 0.23023 train_acc= 0.97143 val_loss= 0.65129 val_acc= 0.82000 test_acc= 0.85300 time= 0.36698
# Epoch: 0589 train_loss= 0.20557 train_acc= 0.97143 val_loss= 0.65119 val_acc= 0.82000 test_acc= 0.85300 time= 0.38114
# Epoch: 0590 train_loss= 0.21010 train_acc= 0.99286 val_loss= 0.65095 val_acc= 0.82000 test_acc= 0.85300 time= 0.37966
# Epoch: 0591 train_loss= 0.19687 train_acc= 0.97143 val_loss= 0.65080 val_acc= 0.82000 test_acc= 0.85300 time= 0.37335
# Epoch: 0592 train_loss= 0.22249 train_acc= 0.97143 val_loss= 0.65043 val_acc= 0.82000 test_acc= 0.85400 time= 0.38808
# Epoch: 0593 train_loss= 0.23139 train_acc= 0.95714 val_loss= 0.65015 val_acc= 0.82000 test_acc= 0.85400 time= 0.39357
# Epoch: 0594 train_loss= 0.22626 train_acc= 0.95714 val_loss= 0.65008 val_acc= 0.82000 test_acc= 0.85400 time= 0.40194
# Epoch: 0595 train_loss= 0.19813 train_acc= 0.99286 val_loss= 0.65000 val_acc= 0.82000 test_acc= 0.85500 time= 0.36695
# Epoch: 0596 train_loss= 0.21303 train_acc= 0.97857 val_loss= 0.64999 val_acc= 0.82000 test_acc= 0.85500 time= 0.39161
# Epoch: 0597 train_loss= 0.20248 train_acc= 0.96429 val_loss= 0.65012 val_acc= 0.82000 test_acc= 0.85500 time= 0.39933
# Epoch: 0598 train_loss= 0.19493 train_acc= 0.98571 val_loss= 0.65006 val_acc= 0.82000 test_acc= 0.85500 time= 0.37752
# Epoch: 0599 train_loss= 0.20558 train_acc= 0.97143 val_loss= 0.65014 val_acc= 0.82000 test_acc= 0.85500 time= 0.37329
# Epoch: 0600 train_loss= 0.16205 train_acc= 0.99286 val_loss= 0.65021 val_acc= 0.82000 test_acc= 0.85500 time= 0.38550
# Epoch: 0601 train_loss= 0.22203 train_acc= 0.97143 val_loss= 0.65015 val_acc= 0.82000 test_acc= 0.85500 time= 0.36432
# Epoch: 0602 train_loss= 0.18587 train_acc= 0.98571 val_loss= 0.65020 val_acc= 0.82000 test_acc= 0.85500 time= 0.37583
# Epoch: 0603 train_loss= 0.21002 train_acc= 0.97143 val_loss= 0.65028 val_acc= 0.82000 test_acc= 0.85500 time= 0.38015
# Epoch: 0604 train_loss= 0.19352 train_acc= 0.97143 val_loss= 0.65035 val_acc= 0.82000 test_acc= 0.85500 time= 0.37438
# Epoch: 0605 train_loss= 0.18449 train_acc= 0.97857 val_loss= 0.65036 val_acc= 0.82000 test_acc= 0.85500 time= 0.36816
# Epoch: 0606 train_loss= 0.18484 train_acc= 0.97857 val_loss= 0.65041 val_acc= 0.82000 test_acc= 0.85500 time= 0.37797
# Epoch: 0607 train_loss= 0.21570 train_acc= 0.97857 val_loss= 0.65048 val_acc= 0.82000 test_acc= 0.85500 time= 0.36233
# Epoch: 0608 train_loss= 0.22736 train_acc= 0.96429 val_loss= 0.65064 val_acc= 0.82000 test_acc= 0.85500 time= 0.37575
# Optimization Finished!
# ----------------------------------------------
# The finall result: 0.8519992
# ----------------------------------------------
